# %% [markdown]
# # 1.读取数据

# %%
import pandas as pd
import time
import numpy as np
train = pd.read_csv('train.csv',dtype={"sexo":str, "ind_nuevo":str, 
                                  "ult_fec_cli_1t":str, 
                                  "indext":str})

test = pd.read_csv("test.csv",dtype={"sexo":str, "ind_nuevo":str, 
                                  "ult_fec_cli_1t":str, 
                                  "indext":str})
# Out:
# C:\Users\xueliang.chen\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (5,8,11,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# # 2.数据预处理

# %% [markdown]
# ### 2.1 查看数据行列

# %%
print(train.shape)
print(test.shape)
print(train.columns)
print(test.columns)
# Out:
# (533770, 48)
# (29162, 24)
# Index(['fecha_dato', 'ncodpers', 'ind_empleado', 'pais_residencia', 'sexo',
#        'age', 'fecha_alta', 'ind_nuevo', 'antiguedad', 'indrel',
#        'ult_fec_cli_1t', 'indrel_1mes', 'tiprel_1mes', 'indresi', 'indext',
#        'conyuemp', 'canal_entrada', 'indfall', 'tipodom', 'cod_prov',
#        'nomprov', 'ind_actividad_cliente', 'renta', 'segmento',
#        'ind_ahor_fin_ult1', 'ind_aval_fin_ult1', 'ind_cco_fin_ult1',
#        'ind_cder_fin_ult1', 'ind_cno_fin_ult1', 'ind_ctju_fin_ult1',
#        'ind_ctma_fin_ult1', 'ind_ctop_fin_ult1', 'ind_ctpp_fin_ult1',
#        'ind_deco_fin_ult1', 'ind_deme_fin_ult1', 'ind_dela_fin_ult1',
#        'ind_ecue_fin_ult1', 'ind_fond_fin_ult1', 'ind_hip_fin_ult1',
#        'ind_plan_fin_ult1', 'ind_pres_fin_ult1', 'ind_reca_fin_ult1',
#        'ind_tjcr_fin_ult1', 'ind_valo_fin_ult1', 'ind_viv_fin_ult1',
#        'ind_nomina_ult1', 'ind_nom_pens_ult1', 'ind_recibo_ult1'],
#       dtype='object')
# Index(['fecha_dato', 'ncodpers', 'ind_empleado', 'pais_residencia', 'sexo',
#        'age', 'fecha_alta', 'ind_nuevo', 'antiguedad', 'indrel',
#        'ult_fec_cli_1t', 'indrel_1mes', 'tiprel_1mes', 'indresi', 'indext',
#        'conyuemp', 'canal_entrada', 'indfall', 'tipodom', 'cod_prov',
#        'nomprov', 'ind_actividad_cliente', 'renta', 'segmento'],
#       dtype='object')

# %% [markdown]
# ##### 训练集比测试集多24个label列

# %% [markdown]
# ### 2.2 处理label

# %%
#对24个label进行处理
targets = train.columns[24:]

#查看label分布
for target in targets:
    print(target+":\n"+str(train[target].value_counts()))
# Out:
# ind_ahor_fin_ult1:
# 0    533722
# 1        48
# Name: ind_ahor_fin_ult1, dtype: int64
# ind_aval_fin_ult1:
# 0    533754
# 1        16
# Name: ind_aval_fin_ult1, dtype: int64
# ind_cco_fin_ult1:
# 1    351209
# 0    182561
# Name: ind_cco_fin_ult1, dtype: int64
# ind_cder_fin_ult1:
# 0    533494
# 1       276
# Name: ind_cder_fin_ult1, dtype: int64
# ind_cno_fin_ult1:
# 0    490450
# 1     43320
# Name: ind_cno_fin_ult1, dtype: int64
# ind_ctju_fin_ult1:
# 0    528637
# 1      5133
# Name: ind_ctju_fin_ult1, dtype: int64
# ind_ctma_fin_ult1:
# 0    528571
# 1      5199
# Name: ind_ctma_fin_ult1, dtype: int64
# ind_ctop_fin_ult1:
# 0    462330
# 1     71440
# Name: ind_ctop_fin_ult1, dtype: int64
# ind_ctpp_fin_ult1:
# 0    509806
# 1     23964
# Name: ind_ctpp_fin_ult1, dtype: int64
# ind_deco_fin_ult1:
# 0    532742
# 1      1028
# Name: ind_deco_fin_ult1, dtype: int64
# ind_deme_fin_ult1:
# 0    533005
# 1       765
# Name: ind_deme_fin_ult1, dtype: int64
# ind_dela_fin_ult1:
# 0    510820
# 1     22950
# Name: ind_dela_fin_ult1, dtype: int64
# ind_ecue_fin_ult1:
# 0    490232
# 1     43538
# Name: ind_ecue_fin_ult1, dtype: int64
# ind_fond_fin_ult1:
# 0    523706
# 1     10064
# Name: ind_fond_fin_ult1, dtype: int64
# ind_hip_fin_ult1:
# 0    530737
# 1      3033
# Name: ind_hip_fin_ult1, dtype: int64
# ind_plan_fin_ult1:
# 0    528657
# 1      5113
# Name: ind_plan_fin_ult1, dtype: int64
# ind_pres_fin_ult1:
# 0    532268
# 1      1502
# Name: ind_pres_fin_ult1, dtype: int64
# ind_reca_fin_ult1:
# 0    504422
# 1     29348
# Name: ind_reca_fin_ult1, dtype: int64
# ind_tjcr_fin_ult1:
# 0    509893
# 1     23877
# Name: ind_tjcr_fin_ult1, dtype: int64
# ind_valo_fin_ult1:
# 0    519522
# 1     14248
# Name: ind_valo_fin_ult1, dtype: int64
# ind_viv_fin_ult1:
# 0    531894
# 1      1876
# Name: ind_viv_fin_ult1, dtype: int64
# ind_nomina_ult1:
# 0.0    504041
# 1.0     29012
# Name: ind_nomina_ult1, dtype: int64
# ind_nom_pens_ult1:
# 0.0    501158
# 1.0     31895
# Name: ind_nom_pens_ult1, dtype: int64
# ind_recibo_ult1:
# 0    464336
# 1     69434
# Name: ind_recibo_ult1, dtype: int64

# %%
#查看缺失值
for target in targets:
    print(target+":"+str(train[target].isnull().sum()))
# Out:
# ind_ahor_fin_ult1:0
# ind_aval_fin_ult1:0
# ind_cco_fin_ult1:0
# ind_cder_fin_ult1:0
# ind_cno_fin_ult1:0
# ind_ctju_fin_ult1:0
# ind_ctma_fin_ult1:0
# ind_ctop_fin_ult1:0
# ind_ctpp_fin_ult1:0
# ind_deco_fin_ult1:0
# ind_deme_fin_ult1:0
# ind_dela_fin_ult1:0
# ind_ecue_fin_ult1:0
# ind_fond_fin_ult1:0
# ind_hip_fin_ult1:0
# ind_plan_fin_ult1:0
# ind_pres_fin_ult1:0
# ind_reca_fin_ult1:0
# ind_tjcr_fin_ult1:0
# ind_valo_fin_ult1:0
# ind_viv_fin_ult1:0
# ind_nomina_ult1:717
# ind_nom_pens_ult1:717
# ind_recibo_ult1:0

# %%
#填充缺失值
train['ind_nom_pens_ult1'].fillna(0,inplace=True)
train['ind_nomina_ult1'].fillna(0,inplace=True)

# %%
#统一label格式
for target in targets:
    train[target] = train[target].astype('int16')

# %% [markdown]
# ### 2.3 删除多余列（有两列缺失值太多）

# %%
train.isnull().sum()
# Out:
# fecha_dato                    0
# ncodpers                      0
# ind_empleado               1146
# pais_residencia            1146
# sexo                       1146
# age                           0
# fecha_alta                 1146
# ind_nuevo                  1146
# antiguedad                    0
# indrel                     1146
# ult_fec_cli_1t           532841
# indrel_1mes                6150
# tiprel_1mes                6150
# indresi                    1146
# indext                     1146
# conyuemp                 533767
# canal_entrada              7661
# indfall                    1146
# tipodom                    1146
# cod_prov                   3769
# nomprov                    3769
# ind_actividad_cliente      1146
# renta                    106821
# segmento                   7782
# ind_ahor_fin_ult1             0
# ind_aval_fin_ult1             0
# ind_cco_fin_ult1              0
# ind_cder_fin_ult1             0
# ind_cno_fin_ult1              0
# ind_ctju_fin_ult1             0
# ind_ctma_fin_ult1             0
# ind_ctop_fin_ult1             0
# ind_ctpp_fin_ult1             0
# ind_deco_fin_ult1             0
# ind_deme_fin_ult1             0
# ind_dela_fin_ult1             0
# ind_ecue_fin_ult1             0
# ind_fond_fin_ult1             0
# ind_hip_fin_ult1              0
# ind_plan_fin_ult1             0
# ind_pres_fin_ult1             0
# ind_reca_fin_ult1             0
# ind_tjcr_fin_ult1             0
# ind_valo_fin_ult1             0
# ind_viv_fin_ult1              0
# ind_nomina_ult1               0
# ind_nom_pens_ult1             0
# ind_recibo_ult1               0
# dtype: int64

# %%
test.isnull().sum()
# Out:
# fecha_dato                   0
# ncodpers                     0
# ind_empleado                 0
# pais_residencia              0
# sexo                         0
# age                          0
# fecha_alta                   0
# ind_nuevo                    0
# antiguedad                   0
# indrel                       0
# ult_fec_cli_1t           29159
# indrel_1mes                  0
# tiprel_1mes                  0
# indresi                      0
# indext                       0
# conyuemp                 29162
# canal_entrada                2
# indfall                      0
# tipodom                      0
# cod_prov                   139
# nomprov                    139
# ind_actividad_cliente        0
# renta                     6757
# segmento                     2
# dtype: int64

# %%
#缺失值太多，故删除
del train['ult_fec_cli_1t']
del test['ult_fec_cli_1t']
del train['conyuemp']
del test['conyuemp']

# %% [markdown]
# ### 2.4 处理其他特征

# %% [markdown]
# ##### 2.4.1 处理 ‘fecha_dato’ 字段

# %%
print(train['fecha_dato'].value_counts())
print(test['fecha_dato'].value_counts())
# Out:
# 2016-04-28    39006
# 2016-03-28    38858
# 2016-02-28    38703
# 2016-01-28    38511
# 2015-12-28    38334
# 2015-11-28    38061
# 2015-10-28    37484
# 2015-09-28    36328
# 2015-08-28    35403
# 2015-07-28    34849
# 2015-06-28    26516
# 2015-05-28    26484
# 2015-04-28    26417
# 2015-03-28    26354
# 2015-02-28    26272
# 2015-01-28    26190
# Name: fecha_dato, dtype: int64
# 2016-05-28    29162
# Name: fecha_dato, dtype: int64

# %%
#转换时间格式
train['fecha_dato']=pd.to_datetime(train['fecha_dato'], format='%Y-%m-%d')
test['fecha_dato']=pd.to_datetime(test['fecha_dato'], format='%Y-%m-%d')

# %%
#构建'year'年和'month'月特征
train['year'] = train['fecha_dato'].dt.year.astype('int16')
train['month'] = train['fecha_dato'].dt.month.astype('int16')
test['year'] = test['fecha_dato'].dt.year.astype('int16')
test['month'] = test['fecha_dato'].dt.month.astype('int16')

# %%
#构建特征时间戳
temp = train['fecha_dato'][0].value

train['timestamp'] = [(int(i.value-temp))/1e11 for i in train['fecha_dato']]
test['timestamp'] = [(int(i.value-temp))/1e11 for i in test['fecha_dato']]

train['timestamp'] = train['timestamp'].astype('int64')
test['timestamp'] = test['timestamp'].astype('int64')

del train['fecha_dato']
del test['fecha_dato']

# %% [markdown]
# ##### 2.4.2 处理 'ncodpers' 字段

# %%
print(train['ncodpers'].value_counts())
print(test['ncodpers'].value_counts())
print(train['ncodpers'].isnull().sum())
print(test['ncodpers'].isnull().sum())
# Out:
# 1058811    16
# 1248435    16
# 1278114    16
# 1052880    16
# 28892      16
#            ..
# 1546226     1
# 1545963     1
# 1542908     1
# 1543440     1
# 1444901     1
# Name: ncodpers, Length: 40000, dtype: int64
# 724990     1
# 1099634    1
# 1031997    1
# 1153550    1
# 1038683    1
#           ..
# 181197     1
# 1131888    1
# 404432     1
# 80850      1
# 1052674    1
# Name: ncodpers, Length: 29162, dtype: int64
# 0
# 0

# %%
train['ncodpers'] = train['ncodpers'].astype('int64')
test['ncodpers'] = test['ncodpers'].astype('int64')

# %% [markdown]
# ##### 2.4.3 处理 'ind_empleado' 字段

# %%
print(train['ind_empleado'].value_counts())
print(test['ind_empleado'].value_counts())
print(train['ind_empleado'].isnull().sum())
print(test['ind_empleado'].isnull().sum())
# Out:
# N    532482
# B        68
# A        32
# F        26
# S        16
# Name: ind_empleado, dtype: int64
# N    29155
# B        3
# A        2
# F        1
# S        1
# Name: ind_empleado, dtype: int64
# 1146
# 0

# %%
#众数填充训练集
train['ind_empleado'].fillna('N',inplace=True)

# %% [markdown]
# ##### 创建列表 le 存放分类特征，后面一块处理

# %%
le = []
le.append('ind_empleado')

# %% [markdown]
# ##### 2.4.4 处理 'pais_residencia' 字段

# %%
print(train['pais_residencia'].value_counts().head())
print(test['pais_residencia'].value_counts().head())
print(train['pais_residencia'].isnull().sum())
print(test['pais_residencia'].isnull().sum())
# Out:
# ES    529970
# DE       256
# FR       210
# AR       196
# CO       192
# Name: pais_residencia, dtype: int64
# ES    29023
# DE       16
# CO       11
# AR       11
# GB       10
# Name: pais_residencia, dtype: int64
# 1146
# 0

# %%
#众数填充训练集
train['pais_residencia'].fillna('ES',inplace=True)

# %%
le.append('pais_residencia')

# %% [markdown]
# ##### 2.4.5 处理 'sexo' 字段

# %%
print(train['sexo'].value_counts())
print(test['sexo'].value_counts())
print(train['sexo'].isnull().sum())
print(test['sexo'].isnull().sum())
# Out:
# V    291340
# H    241284
# Name: sexo, dtype: int64
# V    15724
# H    13438
# Name: sexo, dtype: int64
# 1146
# 0

# %%
#用前一条数据的值填充
train['sexo'].fillna(method='pad', inplace=True)

# %%
le.append('sexo')

# %% [markdown]
# ##### 2.4.6 处理 'age' 字段

# %%
print(train['age'].value_counts())
print(test['age'].value_counts())
print(train['age'].isnull().sum())
print(test['age'].isnull().sum())
# Out:
# 23     20061
# 22     19889
# 24     19398
# 21     19084
# 20     14233
#        ...
# 9          2
# 8          1
# 111        1
# 97         1
# 98         1
# Name: age, Length: 309, dtype: int64
# 24     1786
# 23     1589
# 22     1522
# 21     1395
# 25     1339
#        ...
# 103       2
# 2         1
# 102       1
# 107       1
# 110       1
# Name: age, Length: 107, dtype: int64
# 0
# 0

# %%
train["age"]   = pd.to_numeric(train["age"],errors='coerce')
test['age'] = test['age'].astype('int64')

# %%
#众数填充训练集
train['age'].fillna(23,inplace=True)

train['age'] = train['age'].astype('int64')
test['age'] = test['age'].astype('int64')

# %% [markdown]
# ##### 2.4.7 处理 'fecha_alta' 字段

# %%
print(train['fecha_alta'].value_counts())
print(test['fecha_alta'].value_counts())
print(train['fecha_alta'].isnull().sum())
print(test['fecha_alta'].isnull().sum())
# Out:
# 2014-07-28    2137
# 2014-10-03    2110
# 2013-10-14    2072
# 2014-08-04    1910
# 2013-08-03    1373
#               ...
# 2016-04-09       3
# 2016-02-28       2
# 2006-02-04       2
# 2016-04-03       1
# 2016-04-24       1
# Name: fecha_alta, Length: 5668, dtype: int64
# 2014-07-28    126
# 2014-10-03    112
# 2013-10-14    108
# 2014-08-04    107
# 2013-08-03     78
#              ...
# 2009-03-08      1
# 2008-09-13      1
# 2013-07-12      1
# 2002-07-23      1
# 2010-09-02      1
# Name: fecha_alta, Length: 5279, dtype: int64
# 1146
# 0

# %%
#用众数填充
train['fecha_alta'].fillna('2014-07-28',inplace=True)

# %%
#构建时间特征
train['fecha_alta']=pd.to_datetime(train['fecha_alta'], format='%Y-%m-%d')
test['fecha_alta']=pd.to_datetime(test['fecha_alta'], format='%Y-%m-%d')

train['fyear'] = train['fecha_alta'].dt.year.astype('int16')
train['fmonth'] = train['fecha_alta'].dt.month.astype('int16')
train['fday'] = train['fecha_alta'].dt.day.astype('int16')
test['fyear'] = test['fecha_alta'].dt.year.astype('int16')
test['fmonth'] = test['fecha_alta'].dt.month.astype('int16')
test['fday'] = test['fecha_alta'].dt.day.astype('int16')

train['ftimestamp'] = [(int(i.value))/1e11 for i in train['fecha_alta']]
test['ftimestamp'] = [(int(i.value))/1e11 for i in test['fecha_alta']]
train['ftimestamp'] = train['ftimestamp'].astype('int64')
test['ftimestamp'] = test['ftimestamp'].astype('int64')

# %%
del train['fecha_alta']
del test['fecha_alta']

# %% [markdown]
# ##### 2.4.8 处理 'ind_nuevo' 字段

# %%
print(train['ind_nuevo'].value_counts())
print(test['ind_nuevo'].value_counts())
print(train['ind_nuevo'].isnull().sum())
print(test['ind_nuevo'].isnull().sum())
# Out:
# 0.0    499694
# 1.0     32930
# Name: ind_nuevo, dtype: int64
# 0.0    28317
# 1.0      845
# Name: ind_nuevo, dtype: int64
# 1146
# 0

# %%
train['ind_nuevo'].fillna(0.0,inplace=True)
train['ind_nuevo'] = train['ind_nuevo'].astype('float16')
test['ind_nuevo'] = test['ind_nuevo'].astype('float16')
train['ind_nuevo'] = train['ind_nuevo'].astype('int16')
test['ind_nuevo'] = test['ind_nuevo'].astype('int16')

# %% [markdown]
# ##### 2.4.9 处理 'antiguedad' 字段

# %%
print(train['antiguedad'].value_counts().head())
print(test['antiguedad'].value_counts().head())
print(train['antiguedad'].isnull().sum())
print(test['antiguedad'].isnull().sum())
# Out:
# 0     5490
# 1     5328
# 12    5314
# 3     5078
# 2     5069
# Name: antiguedad, dtype: int64
# 31    811
# 7     759
# 8     749
# 10    742
# 43    657
# Name: antiguedad, dtype: int64
# 0
# 0

# %%
train["antiguedad"]   = pd.to_numeric(train["antiguedad"], errors="coerce")
test['antiguedad'] = test['antiguedad'].astype('int32')
train['antiguedad'].fillna(0,inplace=True)
train['antiguedad'] = train['antiguedad'].astype('int32')

# %% [markdown]
# ##### 2.4.10 处理 'indrel' 字段

# %%
print(train['indrel'].value_counts())
print(test['indrel'].value_counts())
print(train['indrel'].isnull().sum())
print(test['indrel'].isnull().sum())
# Out:
# 1.0     531695
# 99.0       929
# Name: indrel, dtype: int64
# 1.0     29159
# 99.0        3
# Name: indrel, dtype: int64
# 1146
# 0

# %%
train['indrel'].fillna(0,inplace=True)

# %%
train['indrel'] = train['indrel'].astype('int32')
test['indrel'] = test['indrel'].astype('int32')

# %% [markdown]
# ##### 2.4.11 处理 'indrel_1mes' 字段

# %%
print(train['indrel_1mes'].value_counts())
print(test['indrel_1mes'].value_counts())
print(train['indrel_1mes'].isnull().sum())
print(test['indrel_1mes'].isnull().sum())
# Out:
# 1.0    260936
# 1.0    205021
# 1       61417
# 3.0        86
# 3.0        46
# P          29
# 3          26
# 2.0        21
# 2          14
# 2.0        12
# 4.0         6
# 4           3
# 4.0         3
# Name: indrel_1mes, dtype: int64
# 1.0    29160
# 3.0        2
# Name: indrel_1mes, dtype: int64
# 6150
# 0

# %%
train["indrel_1mes"]   = pd.to_numeric(train["indrel_1mes"], errors="coerce")
test['indrel_1mes'] = test['indrel_1mes'].astype('int32')

# %%
train['indrel_1mes'].fillna(5,inplace=True)

train['indrel_1mes'] = train['indrel_1mes'].astype('int32')
test['indrel_1mes'] = test['indrel_1mes'].astype('int32')

# %% [markdown]
# ##### 2.4.12 处理 'tiprel_1mes' 字段

# %%
print(train['tiprel_1mes'].value_counts())
print(test['tiprel_1mes'].value_counts())
print(train['tiprel_1mes'].isnull().sum())
print(test['tiprel_1mes'].isnull().sum())
# Out:
# I    284020
# A    243401
# P       170
# R        29
# Name: tiprel_1mes, dtype: int64
# A    15626
# I    13534
# P        2
# Name: tiprel_1mes, dtype: int64
# 6150
# 0

# %%
train['tiprel_1mes'].fillna('I',inplace=True)

# %%
le.append('tiprel_1mes')

# %% [markdown]
# ##### 2.4.13 处理 'indresi' 字段

# %%
print(train['indresi'].value_counts())
print(test['indresi'].value_counts())
print(train['indresi'].isnull().sum())
print(test['indresi'].isnull().sum())
# Out:
# S    529970
# N      2654
# Name: indresi, dtype: int64
# S    29023
# N      139
# Name: indresi, dtype: int64
# 1146
# 0

# %%
train['indresi'].fillna('S',inplace=True)

# %%
le.append('indresi')

# %% [markdown]
# ##### 2.4.14 处理 'indext' 字段

# %%
print(train['indext'].value_counts())
print(test['indext'].value_counts())

print(train['indext'].isnull().sum())
print(test['indext'].isnull().sum())
# Out:
# N    507155
# S     25469
# Name: indext, dtype: int64
# N    27867
# S     1295
# Name: indext, dtype: int64
# 1146
# 0

# %%
train['indext'].fillna('N',inplace=True)

# %%
le.append('indext')

# %% [markdown]
# ##### 2.4.15 处理 'canal_entrada' 字段

# %%
print(train['canal_entrada'].value_counts())
print(test['canal_entrada'].value_counts())
print(train['canal_entrada'].isnull().sum())
print(test['canal_entrada'].isnull().sum())
# Out:
# KHE    157115
# KAT    131924
# KFC    120673
# KHQ     21496
# KFA     15783
#         ...
# KEU        10
# KBJ        10
# KEC        10
# KCK        10
# KDU        10
# Name: canal_entrada, Length: 135, dtype: int64
# KHE    8588
# KAT    6689
# KFC    5854
# KHQ    2265
# KHM     973
#        ...
# KBY       1
# KAV       1
# KDV       1
# KFR       1
# KCJ       1
# Name: canal_entrada, Length: 127, dtype: int64
# 7661
# 2

# %%
train['canal_entrada'].fillna('KHE',inplace=True)
test['canal_entrada'].fillna('KHE',inplace=True)

# %%
le.append('canal_entrada')

# %% [markdown]
# ##### 2.4.16 处理 'indfall' 字段

# %%
print(train['indfall'].value_counts())
print(test['indfall'].value_counts())

print(train['indfall'].isnull().sum())
print(test['indfall'].isnull().sum())
# Out:
# N    531311
# S      1313
# Name: indfall, dtype: int64
# N    29109
# S       53
# Name: indfall, dtype: int64
# 1146
# 0

# %%
train['indfall'].fillna('N',inplace=True)

# %%
le.append('indfall')

# %% [markdown]
# ##### 2.4.17 处理 'tipodom' 字段

# %%
print(train['tipodom'].value_counts())
print(test['tipodom'].value_counts())

print(train['tipodom'].isnull().sum())
print(test['tipodom'].isnull().sum())
# Out:
# 1.0    532624
# Name: tipodom, dtype: int64
# 1.0    29162
# Name: tipodom, dtype: int64
# 1146
# 0

# %%
#都是1，选择删除特征
del train['tipodom']
del test['tipodom']

# %% [markdown]
# ##### 2.4.18 处理 'cod_prov' 字段

# %%
print(train['cod_prov'].value_counts().head())
print(test['cod_prov'].value_counts().head())
print(train['cod_prov'].isnull().sum())
print(test['cod_prov'].isnull().sum())
# Out:
# 28.0    173162
# 8.0      50295
# 46.0     26182
# 41.0     24350
# 15.0     16850
# Name: cod_prov, dtype: int64
# 28.0    8921
# 8.0     2548
# 46.0    1510
# 41.0    1391
# 15.0     989
# Name: cod_prov, dtype: int64
# 3769
# 139

# %%
#众数填充
train['cod_prov'].fillna('28.0',inplace=True)
test['cod_prov'].fillna('28.0',inplace=True)

# %%
train['cod_prov'] = train['cod_prov'].astype('float64')
test['cod_prov'] = test['cod_prov'].astype('float64')
train['cod_prov'] = train['cod_prov'].astype('int64')
test['cod_prov'] = test['cod_prov'].astype('int64')

# %% [markdown]
# ##### 2.4.19 处理 'nomprov' 字段

# %%
print(train['nomprov'].value_counts().head())
print(test['nomprov'].value_counts().head())
print(train['nomprov'].isnull().sum())
print(test['nomprov'].isnull().sum())
# Out:
# MADRID       173162
# BARCELONA     50295
# VALENCIA      26182
# SEVILLA       24350
# CORUÑA, A     16850
# Name: nomprov, dtype: int64
# MADRID       8921
# BARCELONA    2548
# VALENCIA     1510
# SEVILLA      1391
# CORUÑA, A     989
# Name: nomprov, dtype: int64
# 3769
# 139

# %%
train['nomprov'].fillna('MADRID',inplace=True)
test['nomprov'].fillna('MADRID',inplace=True)

# %%
le.append('nomprov')

# %% [markdown]
# ##### 2.4.20 处理 'ind_actividad_cliente' 字段

# %%
print(train['ind_actividad_cliente'].value_counts())
print(test['ind_actividad_cliente'].value_counts())
print(train['ind_actividad_cliente'].isnull().sum())
print(test['ind_actividad_cliente'].isnull().sum())
# Out:
# 0.0    288361
# 1.0    244263
# Name: ind_actividad_cliente, dtype: int64
# 1.0    16439
# 0.0    12723
# Name: ind_actividad_cliente, dtype: int64
# 1146
# 0

# %%
#填充前一条数据的值
train['ind_actividad_cliente'].fillna(method='pad', inplace=True)

#转换成int型
train['ind_actividad_cliente'] = train['ind_actividad_cliente'].astype('float64')
test['ind_actividad_cliente'] = test['ind_actividad_cliente'].astype('float64')
train['ind_actividad_cliente'] = train['ind_actividad_cliente'].astype('int64')
test['ind_actividad_cliente'] = test['ind_actividad_cliente'].astype('int64')

# %% [markdown]
# ##### 2.4.21 处理 'renta' 字段

# %%
print(train.renta.describe())
print(test.renta.describe())

print(train['renta'].isnull().sum())
print(test['renta'].isnull().sum())
# Out:
# count    4.269490e+05
# mean     1.366034e+05
# std      3.181129e+05
# min      6.773130e+03
# 25%      6.900687e+04
# 50%      1.021422e+05
# 75%      1.567044e+05
# max      2.889440e+07
# Name: renta, dtype: float64
# count    2.240500e+04
# mean     1.360004e+05
# std      3.493648e+05
# min      6.773130e+03
# 25%      6.877887e+04
# 50%      1.013771e+05
# 75%      1.551080e+05
# max      2.889440e+07
# Name: renta, dtype: float64
# 106821
# 6757

# %%
#使用地区收入均值填充缺失值
groups = train.groupby(['nomprov'])
temp = groups['renta'].agg([('means','mean')]).reset_index()

#聚合之后还有缺失值，使用中位数填充
temp.fillna(1.021422e+05,inplace=True)
train = train.merge(temp, on='nomprov', how='left')

#用0暂时填充缺失值
train['renta'].fillna(0,inplace=True)
#当收入为0时，用该地区的平均值替代0
for i in range(len(train['renta'])):
    if train['renta'][i] ==0:
        train['renta'][i] = train['means'][i]
# Out:
# C:\Users\xueliang.chen\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#使用地区收入均值填充缺失值
groups = test.groupby(['nomprov'])
temp = groups['renta'].agg([('means','mean')]).reset_index()

#聚合之后还有缺失值，使用中位数填充
temp.fillna(1.013771e+05,inplace=True)

test = test.merge(temp, on='nomprov', how='left')

test['renta'].fillna(0,inplace=True)

for i in range(len(test['renta'])):
    if test['renta'][i] ==0:
        test['renta'][i] = test['means'][i]
# Out:
# C:\Users\xueliang.chen\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
train['renta'] = train['renta'].astype('float64')
test['renta'] = test['renta'].astype('float64')

# %%
del train['means']
del test ['means']

# %% [markdown]
# ##### 2.4.22 处理 'segmento' 字段

# %%
print(train['segmento'].value_counts())
print(test['segmento'].value_counts())
print(train['segmento'].isnull().sum())
print(test['segmento'].isnull().sum())
# Out:
# 02 - PARTICULARES     313806
# 03 - UNIVERSITARIO    189954
# 01 - TOP               22228
# Name: segmento, dtype: int64
# 02 - PARTICULARES     16124
# 03 - UNIVERSITARIO    11579
# 01 - TOP               1457
# Name: segmento, dtype: int64
# 7782
# 2

# %%
train['segmento'].fillna('02 - PARTICULARES',inplace=True)
test['segmento'].fillna('02 - PARTICULARES',inplace=True)

# %%
le.append('segmento')

# %%
#查看缺失值情况
train.isnull().sum()
# Out:
# ncodpers                 0
# ind_empleado             0
# pais_residencia          0
# sexo                     0
# age                      0
# ind_nuevo                0
# antiguedad               0
# indrel                   0
# indrel_1mes              0
# tiprel_1mes              0
# indresi                  0
# indext                   0
# canal_entrada            0
# indfall                  0
# cod_prov                 0
# nomprov                  0
# ind_actividad_cliente    0
# renta                    0
# segmento                 0
# ind_ahor_fin_ult1        0
# ind_aval_fin_ult1        0
# ind_cco_fin_ult1         0
# ind_cder_fin_ult1        0
# ind_cno_fin_ult1         0
# ind_ctju_fin_ult1        0
# ind_ctma_fin_ult1        0
# ind_ctop_fin_ult1        0
# ind_ctpp_fin_ult1        0
# ind_deco_fin_ult1        0
# ind_deme_fin_ult1        0
# ind_dela_fin_ult1        0
# ind_ecue_fin_ult1        0
# ind_fond_fin_ult1        0
# ind_hip_fin_ult1         0
# ind_plan_fin_ult1        0
# ind_pres_fin_ult1        0
# ind_reca_fin_ult1        0
# ind_tjcr_fin_ult1        0
# ind_valo_fin_ult1        0
# ind_viv_fin_ult1         0
# ind_nomina_ult1          0
# ind_nom_pens_ult1        0
# ind_recibo_ult1          0
# year                     0
# month                    0
# timestamp                0
# fyear                    0
# fmonth                   0
# fday                     0
# ftimestamp               0
# dtype: int64

# %%
#查看缺失值情况
test.isnull().sum()
# Out:
# ncodpers                 0
# ind_empleado             0
# pais_residencia          0
# sexo                     0
# age                      0
# ind_nuevo                0
# antiguedad               0
# indrel                   0
# indrel_1mes              0
# tiprel_1mes              0
# indresi                  0
# indext                   0
# canal_entrada            0
# indfall                  0
# cod_prov                 0
# nomprov                  0
# ind_actividad_cliente    0
# renta                    0
# segmento                 0
# year                     0
# month                    0
# timestamp                0
# fyear                    0
# fmonth                   0
# fday                     0
# ftimestamp               0
# dtype: int64

# %% [markdown]
# ### 2.5分类特征LabelEncoder

# %%
from sklearn.preprocessing import LabelEncoder

# 对于分类特征进行特征值编码
for feature in le:
    lbe=LabelEncoder()
    train[feature]=lbe.fit_transform(train[feature])
    test[feature]=lbe.transform(test[feature])

# %% [markdown]
# # 3.机器学习算法

# %%
import lightgbm as lgb
from sklearn.model_selection import train_test_split

# %%
train_label = pd.DataFrame()
test_label = pd.DataFrame()

# %%
#将label和训练集分离
for column in targets:
    train_label[column] = train[column]
    del train[column]

# %%
#构建一个test副本存放预测值
for column in test.columns:
    test_label[column] = test[column]

# %%
#对于24个标签分别进行预测
for target in targets:
    X_train, X_valid, y_train, y_valid = train_test_split(train, train_label[target], test_size=0.3, random_state=42)
    
    # 创建模型，训练模型
    gbm = lgb.LGBMClassifier(silent=True,num_leaves=51,max_depth=10,boosting_type='gbdt',objective='binary',learning_rate=0.015,n_estimators=1000,
                         subsample=0.75,subsample_freq=2,reg_lambda=0.28,reg_alpha=0.12,colsample_bytree=0.8,min_child_samples=300,min_split_gain=0.1)
    
    gbm.fit(X_train, y_train,eval_set=[(X_train, y_train), (X_valid, y_valid)],eval_metric='auc', early_stopping_rounds=100)
    # 预测数据集
    prob = gbm.predict_proba(test)
    test_label[target] = pd.Series(prob[:,1])
# Out:
# [1]	training's auc: 0.998904	training's binary_logloss: 0.000847617	valid_1's auc: 0.998726	valid_1's binary_logloss: 0.000904904
# Training until validation scores don't improve for 100 rounds
# [2]	training's auc: 0.998963	training's binary_logloss: 0.000785808	valid_1's auc: 0.998347	valid_1's binary_logloss: 0.000849886
# [3]	training's auc: 0.999648	training's binary_logloss: 0.000759052	valid_1's auc: 0.999398	valid_1's binary_logloss: 0.000819156
# [4]	training's auc: 0.999807	training's binary_logloss: 0.000731928	valid_1's auc: 0.999627	valid_1's binary_logloss: 0.000788362
# [5]	training's auc: 0.99979	training's binary_logloss: 0.000678726	valid_1's auc: 0.999642	valid_1's binary_logloss: 0.000739281
# [6]	training's auc: 0.99991	training's binary_logloss: 0.000617604	valid_1's auc: 0.999851	valid_1's binary_logloss: 0.000683383
# [7]	training's auc: 0.999849	training's binary_logloss: 0.000570827	valid_1's auc: 0.999746	valid_1's binary_logloss: 0.000640206
# [8]	training's auc: 0.9999	training's binary_logloss: 0.000537674	valid_1's auc: 0.999831	valid_1's binary_logloss: 0.000610688
# [9]	training's auc: 0.999986	training's binary_logloss: 0.000509403	valid_1's auc: 0.99998	valid_1's binary_logloss: 0.000584077
# [10]	training's auc: 0.999986	training's binary_logloss: 0.000481006	valid_1's auc: 0.99998	valid_1's binary_logloss: 0.000554211
# [11]	training's auc: 0.999986	training's binary_logloss: 0.000451243	valid_1's auc: 0.99998	valid_1's binary_logloss: 0.000526349
# [12]	training's auc: 0.999992	training's binary_logloss: 0.000430976	valid_1's auc: 0.999985	valid_1's binary_logloss: 0.000505613
# [13]	training's auc: 0.999992	training's binary_logloss: 0.000400323	valid_1's auc: 0.999985	valid_1's binary_logloss: 0.000472824
# [14]	training's auc: 0.999992	training's binary_logloss: 0.000378459	valid_1's auc: 0.999985	valid_1's binary_logloss: 0.000444504
# [15]	training's auc: 1	training's binary_logloss: 0.000361791	valid_1's auc: 1	valid_1's binary_logloss: 0.000425432
# [16]	training's auc: 1	training's binary_logloss: 0.000346876	valid_1's auc: 1	valid_1's binary_logloss: 0.000408098
# [17]	training's auc: 1	training's binary_logloss: 0.000335459	valid_1's auc: 1	valid_1's binary_logloss: 0.00039695
# [18]	training's auc: 1	training's binary_logloss: 0.000325227	valid_1's auc: 1	valid_1's binary_logloss: 0.000386822
# [19]	training's auc: 1	training's binary_logloss: 0.000313018	valid_1's auc: 1	valid_1's binary_logloss: 0.000371773
# [20]	training's auc: 1	training's binary_logloss: 0.000302181	valid_1's auc: 1	valid_1's binary_logloss: 0.000358775
# [21]	training's auc: 1	training's binary_logloss: 0.000294377	valid_1's auc: 1	valid_1's binary_logloss: 0.000349678
# [22]	training's auc: 1	training's binary_logloss: 0.000284733	valid_1's auc: 1	valid_1's binary_logloss: 0.000339211
# [23]	training's auc: 1	training's binary_logloss: 0.000275082	valid_1's auc: 1	valid_1's binary_logloss: 0.000327024
# [24]	training's auc: 1	training's binary_logloss: 0.000266372	valid_1's auc: 1	valid_1's binary_logloss: 0.000316065
# [25]	training's auc: 1	training's binary_logloss: 0.000257172	valid_1's auc: 1	valid_1's binary_logloss: 0.000303895
# [26]	training's auc: 1	training's binary_logloss: 0.000248901	valid_1's auc: 1	valid_1's binary_logloss: 0.00029279
# [27]	training's auc: 1	training's binary_logloss: 0.000241641	valid_1's auc: 1	valid_1's binary_logloss: 0.000283758
# [28]	training's auc: 1	training's binary_logloss: 0.000234935	valid_1's auc: 1	valid_1's binary_logloss: 0.000275329
# [29]	training's auc: 1	training's binary_logloss: 0.000228678	valid_1's auc: 1	valid_1's binary_logloss: 0.00026712
# [30]	training's auc: 1	training's binary_logloss: 0.000222343	valid_1's auc: 1	valid_1's binary_logloss: 0.000258967
# [31]	training's auc: 1	training's binary_logloss: 0.000216274	valid_1's auc: 1	valid_1's binary_logloss: 0.00025129
# [32]	training's auc: 1	training's binary_logloss: 0.000210487	valid_1's auc: 1	valid_1's binary_logloss: 0.000244004
# [33]	training's auc: 1	training's binary_logloss: 0.000205366	valid_1's auc: 1	valid_1's binary_logloss: 0.000237803
# [34]	training's auc: 1	training's binary_logloss: 0.000200935	valid_1's auc: 1	valid_1's binary_logloss: 0.000232701
# [35]	training's auc: 1	training's binary_logloss: 0.000195828	valid_1's auc: 1	valid_1's binary_logloss: 0.000226033
# [36]	training's auc: 1	training's binary_logloss: 0.000190771	valid_1's auc: 1	valid_1's binary_logloss: 0.000219559
# [37]	training's auc: 1	training's binary_logloss: 0.000186261	valid_1's auc: 1	valid_1's binary_logloss: 0.000213886
# [38]	training's auc: 1	training's binary_logloss: 0.000181849	valid_1's auc: 1	valid_1's binary_logloss: 0.000208422
# [39]	training's auc: 1	training's binary_logloss: 0.000177718	valid_1's auc: 1	valid_1's binary_logloss: 0.000203343
# [40]	training's auc: 1	training's binary_logloss: 0.000173747	valid_1's auc: 1	valid_1's binary_logloss: 0.000198435
# [41]	training's auc: 1	training's binary_logloss: 0.000169966	valid_1's auc: 1	valid_1's binary_logloss: 0.000193778
# [42]	training's auc: 1	training's binary_logloss: 0.000166337	valid_1's auc: 1	valid_1's binary_logloss: 0.000189256
# [43]	training's auc: 1	training's binary_logloss: 0.000162987	valid_1's auc: 1	valid_1's binary_logloss: 0.000185573
# [44]	training's auc: 1	training's binary_logloss: 0.000159671	valid_1's auc: 1	valid_1's binary_logloss: 0.000181534
# [45]	training's auc: 1	training's binary_logloss: 0.000156459	valid_1's auc: 1	valid_1's binary_logloss: 0.000177996
# [46]	training's auc: 1	training's binary_logloss: 0.000153368	valid_1's auc: 1	valid_1's binary_logloss: 0.000174586
# [47]	training's auc: 1	training's binary_logloss: 0.000150322	valid_1's auc: 1	valid_1's binary_logloss: 0.000170916
# [48]	training's auc: 1	training's binary_logloss: 0.000147428	valid_1's auc: 1	valid_1's binary_logloss: 0.000167422
# [49]	training's auc: 1	training's binary_logloss: 0.000144605	valid_1's auc: 1	valid_1's binary_logloss: 0.000164304
# [50]	training's auc: 1	training's binary_logloss: 0.000141822	valid_1's auc: 1	valid_1's binary_logloss: 0.00016095
# [51]	training's auc: 1	training's binary_logloss: 0.000139128	valid_1's auc: 1	valid_1's binary_logloss: 0.000157684
# [52]	training's auc: 1	training's binary_logloss: 0.000136439	valid_1's auc: 1	valid_1's binary_logloss: 0.000154463
# [53]	training's auc: 1	training's binary_logloss: 0.00013405	valid_1's auc: 1	valid_1's binary_logloss: 0.000151826
# [54]	training's auc: 1	training's binary_logloss: 0.000131736	valid_1's auc: 1	valid_1's binary_logloss: 0.000149269
# [55]	training's auc: 1	training's binary_logloss: 0.000129351	valid_1's auc: 1	valid_1's binary_logloss: 0.000146435
# [56]	training's auc: 1	training's binary_logloss: 0.000127034	valid_1's auc: 1	valid_1's binary_logloss: 0.000143687
# [57]	training's auc: 1	training's binary_logloss: 0.000124943	valid_1's auc: 1	valid_1's binary_logloss: 0.000141376
# [58]	training's auc: 1	training's binary_logloss: 0.000122875	valid_1's auc: 1	valid_1's binary_logloss: 0.000139089
# [59]	training's auc: 1	training's binary_logloss: 0.000120757	valid_1's auc: 1	valid_1's binary_logloss: 0.000136742
# [60]	training's auc: 1	training's binary_logloss: 0.00011871	valid_1's auc: 1	valid_1's binary_logloss: 0.000134287
# [61]	training's auc: 1	training's binary_logloss: 0.00011682	valid_1's auc: 1	valid_1's binary_logloss: 0.000132193
# [62]	training's auc: 1	training's binary_logloss: 0.000114946	valid_1's auc: 1	valid_1's binary_logloss: 0.000130117
# [63]	training's auc: 1	training's binary_logloss: 0.000112994	valid_1's auc: 1	valid_1's binary_logloss: 0.000127782
# [64]	training's auc: 1	training's binary_logloss: 0.000111029	valid_1's auc: 1	valid_1's binary_logloss: 0.000125459
# [65]	training's auc: 1	training's binary_logloss: 0.000109156	valid_1's auc: 1	valid_1's binary_logloss: 0.000123259
# [66]	training's auc: 1	training's binary_logloss: 0.000107472	valid_1's auc: 1	valid_1's binary_logloss: 0.000121391
# [67]	training's auc: 1	training's binary_logloss: 0.000105907	valid_1's auc: 1	valid_1's binary_logloss: 0.000119658
# [68]	training's auc: 1	training's binary_logloss: 0.00010435	valid_1's auc: 1	valid_1's binary_logloss: 0.000117933
# [69]	training's auc: 1	training's binary_logloss: 0.000102771	valid_1's auc: 1	valid_1's binary_logloss: 0.000115991
# [70]	training's auc: 1	training's binary_logloss: 0.000101232	valid_1's auc: 1	valid_1's binary_logloss: 0.0001141
# [71]	training's auc: 1	training's binary_logloss: 9.96547e-05	valid_1's auc: 1	valid_1's binary_logloss: 0.000112345
# [72]	training's auc: 1	training's binary_logloss: 9.8175e-05	valid_1's auc: 1	valid_1's binary_logloss: 0.000110616
# [73]	training's auc: 1	training's binary_logloss: 9.66845e-05	valid_1's auc: 1	valid_1's binary_logloss: 0.00010896
# [74]	training's auc: 1	training's binary_logloss: 9.5232e-05	valid_1's auc: 1	valid_1's binary_logloss: 0.000107346
# [75]	training's auc: 1	training's binary_logloss: 9.38292e-05	valid_1's auc: 1	valid_1's binary_logloss: 0.000105674
# [76]	training's auc: 1	training's binary_logloss: 9.24449e-05	valid_1's auc: 1	valid_1's binary_logloss: 0.000104132
# [77]	training's auc: 1	training's binary_logloss: 9.12005e-05	valid_1's auc: 1	valid_1's binary_logloss: 0.000102753
# [78]	training's auc: 1	training's binary_logloss: 8.99962e-05	valid_1's auc: 1	valid_1's binary_logloss: 0.000101268
# [79]	training's auc: 1	training's binary_logloss: 8.87264e-05	valid_1's auc: 1	valid_1's binary_logloss: 9.98581e-05
# [80]	training's auc: 1	training's binary_logloss: 8.74897e-05	valid_1's auc: 1	valid_1's binary_logloss: 9.84839e-05
# [81]	training's auc: 1	training's binary_logloss: 8.63145e-05	valid_1's auc: 1	valid_1's binary_logloss: 9.70381e-05
# [82]	training's auc: 1	training's binary_logloss: 8.51663e-05	valid_1's auc: 1	valid_1's binary_logloss: 9.56266e-05
# [83]	training's auc: 1	training's binary_logloss: 8.4022e-05	valid_1's auc: 1	valid_1's binary_logloss: 9.43518e-05
# [84]	training's auc: 1	training's binary_logloss: 8.28438e-05	valid_1's auc: 1	valid_1's binary_logloss: 9.30402e-05
# [85]	training's auc: 1	training's binary_logloss: 8.16169e-05	valid_1's auc: 1	valid_1's binary_logloss: 9.16057e-05
# [86]	training's auc: 1	training's binary_logloss: 8.04812e-05	valid_1's auc: 1	valid_1's binary_logloss: 9.02582e-05
# [87]	training's auc: 1	training's binary_logloss: 7.94537e-05	valid_1's auc: 1	valid_1's binary_logloss: 8.91201e-05
# [88]	training's auc: 1	training's binary_logloss: 7.8387e-05	valid_1's auc: 1	valid_1's binary_logloss: 8.79318e-05
# [89]	training's auc: 1	training's binary_logloss: 7.73768e-05	valid_1's auc: 1	valid_1's binary_logloss: 8.68045e-05
# [90]	training's auc: 1	training's binary_logloss: 7.63713e-05	valid_1's auc: 1	valid_1's binary_logloss: 8.56806e-05
# [91]	training's auc: 1	training's binary_logloss: 7.54093e-05	valid_1's auc: 1	valid_1's binary_logloss: 8.46122e-05
# [92]	training's auc: 1	training's binary_logloss: 7.44733e-05	valid_1's auc: 1	valid_1's binary_logloss: 8.35711e-05
# [93]	training's auc: 1	training's binary_logloss: 7.33807e-05	valid_1's auc: 1	valid_1's binary_logloss: 8.23073e-05
# [94]	training's auc: 1	training's binary_logloss: 7.23679e-05	valid_1's auc: 1	valid_1's binary_logloss: 8.11331e-05
# [95]	training's auc: 1	training's binary_logloss: 7.15192e-05	valid_1's auc: 1	valid_1's binary_logloss: 8.01928e-05
# [96]	training's auc: 1	training's binary_logloss: 7.06062e-05	valid_1's auc: 1	valid_1's binary_logloss: 7.91735e-05
# [97]	training's auc: 1	training's binary_logloss: 6.97933e-05	valid_1's auc: 1	valid_1's binary_logloss: 7.82709e-05
# [98]	training's auc: 1	training's binary_logloss: 6.89923e-05	valid_1's auc: 1	valid_1's binary_logloss: 7.73823e-05
# [99]	training's auc: 1	training's binary_logloss: 6.8203e-05	valid_1's auc: 1	valid_1's binary_logloss: 7.65012e-05
# [100]	training's auc: 1	training's binary_logloss: 6.74395e-05	valid_1's auc: 1	valid_1's binary_logloss: 7.56709e-05
# [101]	training's auc: 1	training's binary_logloss: 6.66157e-05	valid_1's auc: 1	valid_1's binary_logloss: 7.47044e-05
# [102]	training's auc: 1	training's binary_logloss: 6.57418e-05	valid_1's auc: 1	valid_1's binary_logloss: 7.36796e-05
# [103]	training's auc: 1	training's binary_logloss: 6.49214e-05	valid_1's auc: 1	valid_1's binary_logloss: 7.27111e-05
# [104]	training's auc: 1	training's binary_logloss: 6.4154e-05	valid_1's auc: 1	valid_1's binary_logloss: 7.18583e-05
# [105]	training's auc: 1	training's binary_logloss: 6.351e-05	valid_1's auc: 1	valid_1's binary_logloss: 7.11462e-05
# [106]	training's auc: 1	training's binary_logloss: 6.28868e-05	valid_1's auc: 1	valid_1's binary_logloss: 7.04567e-05
# [107]	training's auc: 1	training's binary_logloss: 6.2023e-05	valid_1's auc: 1	valid_1's binary_logloss: 6.94789e-05
# [108]	training's auc: 1	training's binary_logloss: 6.14138e-05	valid_1's auc: 1	valid_1's binary_logloss: 6.88207e-05
# [109]	training's auc: 1	training's binary_logloss: 6.06656e-05	valid_1's auc: 1	valid_1's binary_logloss: 6.7981e-05
# [110]	training's auc: 1	training's binary_logloss: 5.99526e-05	valid_1's auc: 1	valid_1's binary_logloss: 6.71338e-05
# [111]	training's auc: 1	training's binary_logloss: 5.91823e-05	valid_1's auc: 1	valid_1's binary_logloss: 6.62462e-05
# [112]	training's auc: 1	training's binary_logloss: 5.85329e-05	valid_1's auc: 1	valid_1's binary_logloss: 6.55241e-05
# [113]	training's auc: 1	training's binary_logloss: 5.77375e-05	valid_1's auc: 1	valid_1's binary_logloss: 6.45939e-05
# [114]	training's auc: 1	training's binary_logloss: 5.69757e-05	valid_1's auc: 1	valid_1's binary_logloss: 6.37055e-05
# [115]	training's auc: 1	training's binary_logloss: 5.63213e-05	valid_1's auc: 1	valid_1's binary_logloss: 6.29693e-05
# Early stopping, best iteration is:
# [15]	training's auc: 1	training's binary_logloss: 0.000361791	valid_1's auc: 1	valid_1's binary_logloss: 0.000425432
# [1]	training's auc: 0.995959	training's binary_logloss: 0.000244783	valid_1's auc: 0.99599	valid_1's binary_logloss: 0.000542967
# Training until validation scores don't improve for 100 rounds
# [2]	training's auc: 0.999532	training's binary_logloss: 0.000236987	valid_1's auc: 0.999563	valid_1's binary_logloss: 0.000525128
# [3]	training's auc: 0.999976	training's binary_logloss: 0.000231279	valid_1's auc: 0.999981	valid_1's binary_logloss: 0.000512151
# [4]	training's auc: 0.999993	training's binary_logloss: 0.000222235	valid_1's auc: 0.999995	valid_1's binary_logloss: 0.000491396
# [5]	training's auc: 0.999993	training's binary_logloss: 0.000214641	valid_1's auc: 0.999995	valid_1's binary_logloss: 0.000474002
# [6]	training's auc: 0.999993	training's binary_logloss: 0.000206824	valid_1's auc: 0.999995	valid_1's binary_logloss: 0.000456072
# [7]	training's auc: 0.999993	training's binary_logloss: 0.00019905	valid_1's auc: 0.999995	valid_1's binary_logloss: 0.000438256
# [8]	training's auc: 0.999993	training's binary_logloss: 0.000191761	valid_1's auc: 0.999995	valid_1's binary_logloss: 0.000421537
# [9]	training's auc: 0.999993	training's binary_logloss: 0.000187373	valid_1's auc: 0.999995	valid_1's binary_logloss: 0.000411596
# [10]	training's auc: 0.999992	training's binary_logloss: 0.000185134	valid_1's auc: 0.999993	valid_1's binary_logloss: 0.00040784
# [11]	training's auc: 0.999992	training's binary_logloss: 0.000177645	valid_1's auc: 0.999993	valid_1's binary_logloss: 0.000390653
# [12]	training's auc: 0.999992	training's binary_logloss: 0.000170366	valid_1's auc: 0.999993	valid_1's binary_logloss: 0.00037394
# [13]	training's auc: 0.999992	training's binary_logloss: 0.000166995	valid_1's auc: 0.999993	valid_1's binary_logloss: 0.000366385
# [14]	training's auc: 0.999992	training's binary_logloss: 0.000163667	valid_1's auc: 0.999993	valid_1's binary_logloss: 0.000358924
# [15]	training's auc: 0.999992	training's binary_logloss: 0.000159567	valid_1's auc: 0.999993	valid_1's binary_logloss: 0.000349658
# [16]	training's auc: 0.999992	training's binary_logloss: 0.000155534	valid_1's auc: 0.999993	valid_1's binary_logloss: 0.000340531
# [17]	training's auc: 0.999992	training's binary_logloss: 0.000149928	valid_1's auc: 0.999993	valid_1's binary_logloss: 0.00032768
# [18]	training's auc: 0.999992	training's binary_logloss: 0.000144174	valid_1's auc: 0.999993	valid_1's binary_logloss: 0.00031449
# [19]	training's auc: 0.999992	training's binary_logloss: 0.000137804	valid_1's auc: 0.999993	valid_1's binary_logloss: 0.000299828
# [20]	training's auc: 0.999992	training's binary_logloss: 0.000132052	valid_1's auc: 0.999993	valid_1's binary_logloss: 0.00028657
# [21]	training's auc: 0.999992	training's binary_logloss: 0.000127464	valid_1's auc: 0.999993	valid_1's binary_logloss: 0.000276023
# [22]	training's auc: 0.999994	training's binary_logloss: 0.000124903	valid_1's auc: 0.999993	valid_1's binary_logloss: 0.00027274
# [23]	training's auc: 0.999994	training's binary_logloss: 0.000119297	valid_1's auc: 0.999993	valid_1's binary_logloss: 0.000259807
# [24]	training's auc: 0.999994	training's binary_logloss: 0.000114025	valid_1's auc: 0.999993	valid_1's binary_logloss: 0.000247641
# [25]	training's auc: 0.999994	training's binary_logloss: 0.000108803	valid_1's auc: 0.999993	valid_1's binary_logloss: 0.00023559
# [26]	training's auc: 0.999994	training's binary_logloss: 0.000104484	valid_1's auc: 0.999993	valid_1's binary_logloss: 0.000225601
# [27]	training's auc: 0.999993	training's binary_logloss: 0.000101097	valid_1's auc: 0.999993	valid_1's binary_logloss: 0.000217824
# [28]	training's auc: 0.999993	training's binary_logloss: 9.79893e-05	valid_1's auc: 0.999993	valid_1's binary_logloss: 0.000210681
# [29]	training's auc: 0.999993	training's binary_logloss: 9.53891e-05	valid_1's auc: 0.999993	valid_1's binary_logloss: 0.000204729
# [30]	training's auc: 0.999996	training's binary_logloss: 9.26263e-05	valid_1's auc: 0.999995	valid_1's binary_logloss: 0.000199314
# [31]	training's auc: 0.999996	training's binary_logloss: 8.92203e-05	valid_1's auc: 0.999996	valid_1's binary_logloss: 0.000191462
# [32]	training's auc: 0.999996	training's binary_logloss: 8.6547e-05	valid_1's auc: 0.999996	valid_1's binary_logloss: 0.000185257
# [33]	training's auc: 0.999996	training's binary_logloss: 8.41027e-05	valid_1's auc: 0.999996	valid_1's binary_logloss: 0.000179656
# [34]	training's auc: 0.999996	training's binary_logloss: 8.17051e-05	valid_1's auc: 0.999998	valid_1's binary_logloss: 0.000174144
# [35]	training's auc: 0.999997	training's binary_logloss: 7.97444e-05	valid_1's auc: 0.999998	valid_1's binary_logloss: 0.000171902
# [36]	training's auc: 0.999997	training's binary_logloss: 7.79505e-05	valid_1's auc: 0.999998	valid_1's binary_logloss: 0.000169776
# [37]	training's auc: 0.999997	training's binary_logloss: 7.56976e-05	valid_1's auc: 0.999998	valid_1's binary_logloss: 0.000164554
# [38]	training's auc: 0.999997	training's binary_logloss: 7.33765e-05	valid_1's auc: 0.999998	valid_1's binary_logloss: 0.000159164
# [39]	training's auc: 0.999997	training's binary_logloss: 7.15247e-05	valid_1's auc: 0.999998	valid_1's binary_logloss: 0.000154877
# [40]	training's auc: 0.999997	training's binary_logloss: 7.00415e-05	valid_1's auc: 0.999998	valid_1's binary_logloss: 0.000152932
# [41]	training's auc: 0.999997	training's binary_logloss: 6.88775e-05	valid_1's auc: 0.999998	valid_1's binary_logloss: 0.000150821
# [42]	training's auc: 0.999997	training's binary_logloss: 6.76898e-05	valid_1's auc: 0.999998	valid_1's binary_logloss: 0.000148379
# [43]	training's auc: 0.999997	training's binary_logloss: 6.69937e-05	valid_1's auc: 0.999998	valid_1's binary_logloss: 0.000147904
# [44]	training's auc: 0.999997	training's binary_logloss: 6.63324e-05	valid_1's auc: 0.999998	valid_1's binary_logloss: 0.000147468
# [45]	training's auc: 0.999997	training's binary_logloss: 6.53787e-05	valid_1's auc: 0.999998	valid_1's binary_logloss: 0.000145369
# [46]	training's auc: 0.999997	training's binary_logloss: 6.42445e-05	valid_1's auc: 0.999998	valid_1's binary_logloss: 0.000142827
# [47]	training's auc: 0.999997	training's binary_logloss: 6.30458e-05	valid_1's auc: 0.999998	valid_1's binary_logloss: 0.000140377
# [48]	training's auc: 0.999997	training's binary_logloss: 6.16547e-05	valid_1's auc: 0.999998	valid_1's binary_logloss: 0.000137126
# [49]	training's auc: 0.999997	training's binary_logloss: 6.0447e-05	valid_1's auc: 0.999998	valid_1's binary_logloss: 0.000134302
# [50]	training's auc: 0.999997	training's binary_logloss: 5.91281e-05	valid_1's auc: 0.999998	valid_1's binary_logloss: 0.000131619
# [51]	training's auc: 0.999997	training's binary_logloss: 5.79483e-05	valid_1's auc: 0.999998	valid_1's binary_logloss: 0.000128833
# [52]	training's auc: 0.999997	training's binary_logloss: 5.68772e-05	valid_1's auc: 0.999998	valid_1's binary_logloss: 0.000126314
# [53]	training's auc: 0.999997	training's binary_logloss: 5.5475e-05	valid_1's auc: 0.999998	valid_1's binary_logloss: 0.000123427
# [54]	training's auc: 0.999997	training's binary_logloss: 5.42487e-05	valid_1's auc: 0.999998	valid_1's binary_logloss: 0.000120894
# [55]	training's auc: 0.999998	training's binary_logloss: 5.34468e-05	valid_1's auc: 0.999998	valid_1's binary_logloss: 0.00011972
# [56]	training's auc: 0.999998	training's binary_logloss: 5.25666e-05	valid_1's auc: 0.999998	valid_1's binary_logloss: 0.000118323
# [57]	training's auc: 0.999998	training's binary_logloss: 5.14511e-05	valid_1's auc: 0.999998	valid_1's binary_logloss: 0.000115665
# [58]	training's auc: 0.999998	training's binary_logloss: 5.05666e-05	valid_1's auc: 0.999998	valid_1's binary_logloss: 0.000113516
# [59]	training's auc: 0.999998	training's binary_logloss: 4.95422e-05	valid_1's auc: 0.999998	valid_1's binary_logloss: 0.000111493
# [60]	training's auc: 0.999998	training's binary_logloss: 4.85829e-05	valid_1's auc: 0.999998	valid_1's binary_logloss: 0.000109606
# [61]	training's auc: 0.999998	training's binary_logloss: 4.77703e-05	valid_1's auc: 0.999998	valid_1's binary_logloss: 0.000108553
# [62]	training's auc: 0.999998	training's binary_logloss: 4.69244e-05	valid_1's auc: 0.999999	valid_1's binary_logloss: 0.000107718
# [63]	training's auc: 0.999998	training's binary_logloss: 4.60052e-05	valid_1's auc: 0.999999	valid_1's binary_logloss: 0.000105805
# [64]	training's auc: 0.999998	training's binary_logloss: 4.51479e-05	valid_1's auc: 0.999999	valid_1's binary_logloss: 0.000104001
# [65]	training's auc: 0.999998	training's binary_logloss: 4.45942e-05	valid_1's auc: 0.999999	valid_1's binary_logloss: 0.00010339
# [66]	training's auc: 0.999998	training's binary_logloss: 4.39631e-05	valid_1's auc: 0.999999	valid_1's binary_logloss: 0.000102695
# [67]	training's auc: 0.999998	training's binary_logloss: 4.31464e-05	valid_1's auc: 0.999999	valid_1's binary_logloss: 0.000100673
# [68]	training's auc: 0.999998	training's binary_logloss: 4.24786e-05	valid_1's auc: 0.999999	valid_1's binary_logloss: 9.8993e-05
# [69]	training's auc: 0.999998	training's binary_logloss: 4.2167e-05	valid_1's auc: 0.999999	valid_1's binary_logloss: 9.87583e-05
# [70]	training's auc: 0.999998	training's binary_logloss: 4.18414e-05	valid_1's auc: 0.999999	valid_1's binary_logloss: 9.8006e-05
# [71]	training's auc: 0.999998	training's binary_logloss: 4.13026e-05	valid_1's auc: 0.999999	valid_1's binary_logloss: 9.66423e-05
# [72]	training's auc: 0.999998	training's binary_logloss: 4.06587e-05	valid_1's auc: 0.999999	valid_1's binary_logloss: 9.53282e-05
# [73]	training's auc: 0.999998	training's binary_logloss: 4.00402e-05	valid_1's auc: 0.999999	valid_1's binary_logloss: 9.41061e-05
# [74]	training's auc: 0.999998	training's binary_logloss: 3.9445e-05	valid_1's auc: 0.999999	valid_1's binary_logloss: 9.31854e-05
# [75]	training's auc: 0.999998	training's binary_logloss: 3.89723e-05	valid_1's auc: 0.999999	valid_1's binary_logloss: 9.25235e-05
# [76]	training's auc: 0.999998	training's binary_logloss: 3.8518e-05	valid_1's auc: 0.999999	valid_1's binary_logloss: 9.18971e-05
# [77]	training's auc: 0.999998	training's binary_logloss: 3.80158e-05	valid_1's auc: 0.999999	valid_1's binary_logloss: 9.08603e-05
# [78]	training's auc: 0.999998	training's binary_logloss: 3.75064e-05	valid_1's auc: 0.999999	valid_1's binary_logloss: 8.95716e-05
# [79]	training's auc: 0.999998	training's binary_logloss: 3.70285e-05	valid_1's auc: 0.999999	valid_1's binary_logloss: 8.88385e-05
# [80]	training's auc: 0.999998	training's binary_logloss: 3.65407e-05	valid_1's auc: 0.999999	valid_1's binary_logloss: 8.80934e-05
# [81]	training's auc: 0.999998	training's binary_logloss: 3.62773e-05	valid_1's auc: 0.999999	valid_1's binary_logloss: 8.74602e-05
# [82]	training's auc: 0.999998	training's binary_logloss: 3.5978e-05	valid_1's auc: 0.999999	valid_1's binary_logloss: 8.68664e-05
# [83]	training's auc: 0.999998	training's binary_logloss: 3.55164e-05	valid_1's auc: 0.999999	valid_1's binary_logloss: 8.57753e-05
# [84]	training's auc: 0.999998	training's binary_logloss: 3.52337e-05	valid_1's auc: 0.999999	valid_1's binary_logloss: 8.50529e-05
# [85]	training's auc: 0.999998	training's binary_logloss: 3.48648e-05	valid_1's auc: 0.999999	valid_1's binary_logloss: 8.40976e-05
# [86]	training's auc: 0.999998	training's binary_logloss: 3.43392e-05	valid_1's auc: 0.999999	valid_1's binary_logloss: 8.30305e-05
# [87]	training's auc: 0.999998	training's binary_logloss: 3.3875e-05	valid_1's auc: 0.999999	valid_1's binary_logloss: 8.18124e-05
# [88]	training's auc: 0.999998	training's binary_logloss: 3.34734e-05	valid_1's auc: 0.999999	valid_1's binary_logloss: 8.13021e-05
# [89]	training's auc: 0.999998	training's binary_logloss: 3.2918e-05	valid_1's auc: 0.999999	valid_1's binary_logloss: 8.01226e-05
# [90]	training's auc: 0.999998	training's binary_logloss: 3.23787e-05	valid_1's auc: 0.999999	valid_1's binary_logloss: 7.89758e-05
# [91]	training's auc: 0.999999	training's binary_logloss: 3.21686e-05	valid_1's auc: 0.999999	valid_1's binary_logloss: 7.87005e-05
# [92]	training's auc: 0.999999	training's binary_logloss: 3.19663e-05	valid_1's auc: 0.999999	valid_1's binary_logloss: 7.84401e-05
# [93]	training's auc: 0.999999	training's binary_logloss: 3.14976e-05	valid_1's auc: 0.999999	valid_1's binary_logloss: 7.72224e-05
# [94]	training's auc: 0.999999	training's binary_logloss: 3.09796e-05	valid_1's auc: 0.999999	valid_1's binary_logloss: 7.58892e-05
# [95]	training's auc: 0.999999	training's binary_logloss: 3.07702e-05	valid_1's auc: 0.999999	valid_1's binary_logloss: 7.53527e-05
# [96]	training's auc: 0.999999	training's binary_logloss: 3.05659e-05	valid_1's auc: 0.999999	valid_1's binary_logloss: 7.4828e-05
# [97]	training's auc: 0.999999	training's binary_logloss: 3.03473e-05	valid_1's auc: 0.999999	valid_1's binary_logloss: 7.42384e-05
# [98]	training's auc: 0.999999	training's binary_logloss: 3.01115e-05	valid_1's auc: 0.999999	valid_1's binary_logloss: 7.37227e-05
# [99]	training's auc: 0.999999	training's binary_logloss: 2.96538e-05	valid_1's auc: 0.999999	valid_1's binary_logloss: 7.27458e-05
# [100]	training's auc: 0.999999	training's binary_logloss: 2.92456e-05	valid_1's auc: 0.999999	valid_1's binary_logloss: 7.19816e-05
# [101]	training's auc: 0.999999	training's binary_logloss: 2.88983e-05	valid_1's auc: 0.999999	valid_1's binary_logloss: 7.12698e-05
# [102]	training's auc: 0.999999	training's binary_logloss: 2.85878e-05	valid_1's auc: 0.999999	valid_1's binary_logloss: 7.05294e-05
# [103]	training's auc: 0.999999	training's binary_logloss: 2.82657e-05	valid_1's auc: 0.999999	valid_1's binary_logloss: 6.96634e-05
# [104]	training's auc: 0.999999	training's binary_logloss: 2.79554e-05	valid_1's auc: 0.999999	valid_1's binary_logloss: 6.90159e-05
# [105]	training's auc: 1	training's binary_logloss: 2.76271e-05	valid_1's auc: 0.999999	valid_1's binary_logloss: 6.83702e-05
# [106]	training's auc: 1	training's binary_logloss: 2.7306e-05	valid_1's auc: 1	valid_1's binary_logloss: 6.77386e-05
# [107]	training's auc: 1	training's binary_logloss: 2.69866e-05	valid_1's auc: 1	valid_1's binary_logloss: 6.72519e-05
# [108]	training's auc: 1	training's binary_logloss: 2.66741e-05	valid_1's auc: 1	valid_1's binary_logloss: 6.67769e-05
# [109]	training's auc: 1	training's binary_logloss: 2.65423e-05	valid_1's auc: 0.999999	valid_1's binary_logloss: 6.64841e-05
# [110]	training's auc: 1	training's binary_logloss: 2.6363e-05	valid_1's auc: 0.999999	valid_1's binary_logloss: 6.62051e-05
# [111]	training's auc: 1	training's binary_logloss: 2.6225e-05	valid_1's auc: 0.999999	valid_1's binary_logloss: 6.58431e-05
# [112]	training's auc: 1	training's binary_logloss: 2.604e-05	valid_1's auc: 0.999999	valid_1's binary_logloss: 6.55787e-05
# [113]	training's auc: 1	training's binary_logloss: 2.5731e-05	valid_1's auc: 1	valid_1's binary_logloss: 6.48743e-05
# [114]	training's auc: 1	training's binary_logloss: 2.54752e-05	valid_1's auc: 1	valid_1's binary_logloss: 6.42382e-05
# [115]	training's auc: 1	training's binary_logloss: 2.52377e-05	valid_1's auc: 1	valid_1's binary_logloss: 6.36881e-05
# [116]	training's auc: 1	training's binary_logloss: 2.49527e-05	valid_1's auc: 1	valid_1's binary_logloss: 6.30147e-05
# [117]	training's auc: 1	training's binary_logloss: 2.46944e-05	valid_1's auc: 1	valid_1's binary_logloss: 6.25657e-05
# [118]	training's auc: 1	training's binary_logloss: 2.44244e-05	valid_1's auc: 1	valid_1's binary_logloss: 6.21865e-05
# [119]	training's auc: 1	training's binary_logloss: 2.41483e-05	valid_1's auc: 1	valid_1's binary_logloss: 6.14443e-05
# [120]	training's auc: 1	training's binary_logloss: 2.38876e-05	valid_1's auc: 1	valid_1's binary_logloss: 6.07961e-05
# [121]	training's auc: 1	training's binary_logloss: 2.36412e-05	valid_1's auc: 1	valid_1's binary_logloss: 6.04565e-05
# [122]	training's auc: 1	training's binary_logloss: 2.34769e-05	valid_1's auc: 1	valid_1's binary_logloss: 6.00548e-05
# [123]	training's auc: 1	training's binary_logloss: 2.33163e-05	valid_1's auc: 1	valid_1's binary_logloss: 5.96653e-05
# [124]	training's auc: 1	training's binary_logloss: 2.3169e-05	valid_1's auc: 1	valid_1's binary_logloss: 5.93051e-05
# [125]	training's auc: 1	training's binary_logloss: 2.2946e-05	valid_1's auc: 1	valid_1's binary_logloss: 5.88811e-05
# [126]	training's auc: 1	training's binary_logloss: 2.2686e-05	valid_1's auc: 1	valid_1's binary_logloss: 5.83862e-05
# [127]	training's auc: 1	training's binary_logloss: 2.2401e-05	valid_1's auc: 1	valid_1's binary_logloss: 5.78341e-05
# [128]	training's auc: 1	training's binary_logloss: 2.21883e-05	valid_1's auc: 1	valid_1's binary_logloss: 5.73338e-05
# [129]	training's auc: 1	training's binary_logloss: 2.19396e-05	valid_1's auc: 1	valid_1's binary_logloss: 5.66332e-05
# [130]	training's auc: 1	training's binary_logloss: 2.16694e-05	valid_1's auc: 1	valid_1's binary_logloss: 5.58687e-05
# [131]	training's auc: 1	training's binary_logloss: 2.14596e-05	valid_1's auc: 1	valid_1's binary_logloss: 5.53625e-05
# [132]	training's auc: 1	training's binary_logloss: 2.12561e-05	valid_1's auc: 1	valid_1's binary_logloss: 5.48774e-05
# [133]	training's auc: 1	training's binary_logloss: 2.10512e-05	valid_1's auc: 1	valid_1's binary_logloss: 5.44286e-05
# [134]	training's auc: 1	training's binary_logloss: 2.08543e-05	valid_1's auc: 1	valid_1's binary_logloss: 5.4039e-05
# [135]	training's auc: 1	training's binary_logloss: 2.07685e-05	valid_1's auc: 1	valid_1's binary_logloss: 5.40622e-05
# [136]	training's auc: 1	training's binary_logloss: 2.06849e-05	valid_1's auc: 1	valid_1's binary_logloss: 5.40874e-05
# [137]	training's auc: 1	training's binary_logloss: 2.05675e-05	valid_1's auc: 1	valid_1's binary_logloss: 5.39187e-05
# [138]	training's auc: 1	training's binary_logloss: 2.04525e-05	valid_1's auc: 1	valid_1's binary_logloss: 5.37541e-05
# [139]	training's auc: 1	training's binary_logloss: 2.03059e-05	valid_1's auc: 1	valid_1's binary_logloss: 5.36679e-05
# [140]	training's auc: 1	training's binary_logloss: 2.01902e-05	valid_1's auc: 1	valid_1's binary_logloss: 5.37792e-05
# [141]	training's auc: 1	training's binary_logloss: 2.00186e-05	valid_1's auc: 1	valid_1's binary_logloss: 5.36113e-05
# [142]	training's auc: 1	training's binary_logloss: 1.98501e-05	valid_1's auc: 1	valid_1's binary_logloss: 5.34476e-05
# [143]	training's auc: 1	training's binary_logloss: 1.96669e-05	valid_1's auc: 1	valid_1's binary_logloss: 5.30975e-05
# [144]	training's auc: 1	training's binary_logloss: 1.94863e-05	valid_1's auc: 1	valid_1's binary_logloss: 5.27524e-05
# [145]	training's auc: 1	training's binary_logloss: 1.92863e-05	valid_1's auc: 1	valid_1's binary_logloss: 5.23017e-05
# [146]	training's auc: 1	training's binary_logloss: 1.90963e-05	valid_1's auc: 1	valid_1's binary_logloss: 5.18452e-05
# [147]	training's auc: 1	training's binary_logloss: 1.8936e-05	valid_1's auc: 1	valid_1's binary_logloss: 5.14617e-05
# [148]	training's auc: 1	training's binary_logloss: 1.87697e-05	valid_1's auc: 1	valid_1's binary_logloss: 5.10608e-05
# [149]	training's auc: 1	training's binary_logloss: 1.86547e-05	valid_1's auc: 1	valid_1's binary_logloss: 5.0803e-05
# [150]	training's auc: 1	training's binary_logloss: 1.8542e-05	valid_1's auc: 1	valid_1's binary_logloss: 5.05502e-05
# [151]	training's auc: 1	training's binary_logloss: 1.84544e-05	valid_1's auc: 1	valid_1's binary_logloss: 5.04415e-05
# [152]	training's auc: 1	training's binary_logloss: 1.83686e-05	valid_1's auc: 1	valid_1's binary_logloss: 5.03355e-05
# [153]	training's auc: 1	training's binary_logloss: 1.82012e-05	valid_1's auc: 1	valid_1's binary_logloss: 4.99372e-05
# [154]	training's auc: 1	training's binary_logloss: 1.8008e-05	valid_1's auc: 1	valid_1's binary_logloss: 4.95149e-05
# [155]	training's auc: 1	training's binary_logloss: 1.78561e-05	valid_1's auc: 1	valid_1's binary_logloss: 4.91806e-05
# [156]	training's auc: 1	training's binary_logloss: 1.76871e-05	valid_1's auc: 1	valid_1's binary_logloss: 4.88326e-05
# [157]	training's auc: 1	training's binary_logloss: 1.75813e-05	valid_1's auc: 1	valid_1's binary_logloss: 4.84607e-05
# [158]	training's auc: 1	training's binary_logloss: 1.73947e-05	valid_1's auc: 1	valid_1's binary_logloss: 4.80706e-05
# [159]	training's auc: 1	training's binary_logloss: 1.72517e-05	valid_1's auc: 1	valid_1's binary_logloss: 4.75835e-05
# [160]	training's auc: 1	training's binary_logloss: 1.71063e-05	valid_1's auc: 1	valid_1's binary_logloss: 4.70814e-05
# [161]	training's auc: 1	training's binary_logloss: 1.69941e-05	valid_1's auc: 1	valid_1's binary_logloss: 4.69655e-05
# [162]	training's auc: 1	training's binary_logloss: 1.68873e-05	valid_1's auc: 1	valid_1's binary_logloss: 4.68644e-05
# [163]	training's auc: 1	training's binary_logloss: 1.68126e-05	valid_1's auc: 1	valid_1's binary_logloss: 4.67674e-05
# [164]	training's auc: 1	training's binary_logloss: 1.67179e-05	valid_1's auc: 1	valid_1's binary_logloss: 4.66924e-05
# [165]	training's auc: 1	training's binary_logloss: 1.66679e-05	valid_1's auc: 1	valid_1's binary_logloss: 4.66059e-05
# [166]	training's auc: 1	training's binary_logloss: 1.66197e-05	valid_1's auc: 1	valid_1's binary_logloss: 4.65234e-05
# [167]	training's auc: 1	training's binary_logloss: 1.64762e-05	valid_1's auc: 1	valid_1's binary_logloss: 4.63111e-05
# [168]	training's auc: 1	training's binary_logloss: 1.63345e-05	valid_1's auc: 1	valid_1's binary_logloss: 4.61093e-05
# [169]	training's auc: 1	training's binary_logloss: 1.62111e-05	valid_1's auc: 1	valid_1's binary_logloss: 4.583e-05
# [170]	training's auc: 1	training's binary_logloss: 1.61196e-05	valid_1's auc: 1	valid_1's binary_logloss: 4.57389e-05
# [171]	training's auc: 1	training's binary_logloss: 1.60121e-05	valid_1's auc: 1	valid_1's binary_logloss: 4.57163e-05
# [172]	training's auc: 1	training's binary_logloss: 1.59003e-05	valid_1's auc: 1	valid_1's binary_logloss: 4.56378e-05
# [173]	training's auc: 1	training's binary_logloss: 1.57812e-05	valid_1's auc: 1	valid_1's binary_logloss: 4.53308e-05
# [174]	training's auc: 1	training's binary_logloss: 1.56483e-05	valid_1's auc: 1	valid_1's binary_logloss: 4.49765e-05
# [175]	training's auc: 1	training's binary_logloss: 1.55513e-05	valid_1's auc: 1	valid_1's binary_logloss: 4.47681e-05
# [176]	training's auc: 1	training's binary_logloss: 1.54587e-05	valid_1's auc: 1	valid_1's binary_logloss: 4.45703e-05
# [177]	training's auc: 1	training's binary_logloss: 1.53862e-05	valid_1's auc: 1	valid_1's binary_logloss: 4.44565e-05
# [178]	training's auc: 1	training's binary_logloss: 1.53112e-05	valid_1's auc: 1	valid_1's binary_logloss: 4.43378e-05
# [179]	training's auc: 1	training's binary_logloss: 1.52672e-05	valid_1's auc: 1	valid_1's binary_logloss: 4.42047e-05
# [180]	training's auc: 1	training's binary_logloss: 1.52241e-05	valid_1's auc: 1	valid_1's binary_logloss: 4.4074e-05
# [181]	training's auc: 1	training's binary_logloss: 1.50997e-05	valid_1's auc: 1	valid_1's binary_logloss: 4.37846e-05
# [182]	training's auc: 1	training's binary_logloss: 1.49956e-05	valid_1's auc: 1	valid_1's binary_logloss: 4.34739e-05
# [183]	training's auc: 1	training's binary_logloss: 1.49153e-05	valid_1's auc: 1	valid_1's binary_logloss: 4.32653e-05
# [184]	training's auc: 1	training's binary_logloss: 1.47814e-05	valid_1's auc: 1	valid_1's binary_logloss: 4.29662e-05
# [185]	training's auc: 1	training's binary_logloss: 1.46679e-05	valid_1's auc: 1	valid_1's binary_logloss: 4.26082e-05
# [186]	training's auc: 1	training's binary_logloss: 1.45563e-05	valid_1's auc: 1	valid_1's binary_logloss: 4.22646e-05
# [187]	training's auc: 1	training's binary_logloss: 1.44697e-05	valid_1's auc: 1	valid_1's binary_logloss: 4.21729e-05
# [188]	training's auc: 1	training's binary_logloss: 1.43856e-05	valid_1's auc: 1	valid_1's binary_logloss: 4.20863e-05
# [189]	training's auc: 1	training's binary_logloss: 1.42706e-05	valid_1's auc: 1	valid_1's binary_logloss: 4.17497e-05
# [190]	training's auc: 1	training's binary_logloss: 1.41672e-05	valid_1's auc: 1	valid_1's binary_logloss: 4.14838e-05
# [191]	training's auc: 1	training's binary_logloss: 1.41307e-05	valid_1's auc: 1	valid_1's binary_logloss: 4.14773e-05
# [192]	training's auc: 1	training's binary_logloss: 1.40951e-05	valid_1's auc: 1	valid_1's binary_logloss: 4.14718e-05
# [193]	training's auc: 1	training's binary_logloss: 1.40059e-05	valid_1's auc: 1	valid_1's binary_logloss: 4.12272e-05
# [194]	training's auc: 1	training's binary_logloss: 1.38902e-05	valid_1's auc: 1	valid_1's binary_logloss: 4.09796e-05
# [195]	training's auc: 1	training's binary_logloss: 1.38275e-05	valid_1's auc: 1	valid_1's binary_logloss: 4.09407e-05
# [196]	training's auc: 1	training's binary_logloss: 1.37785e-05	valid_1's auc: 1	valid_1's binary_logloss: 4.07518e-05
# [197]	training's auc: 1	training's binary_logloss: 1.37384e-05	valid_1's auc: 1	valid_1's binary_logloss: 4.08222e-05
# [198]	training's auc: 1	training's binary_logloss: 1.36995e-05	valid_1's auc: 1	valid_1's binary_logloss: 4.08935e-05
# [199]	training's auc: 1	training's binary_logloss: 1.364e-05	valid_1's auc: 1	valid_1's binary_logloss: 4.07682e-05
# [200]	training's auc: 1	training's binary_logloss: 1.35818e-05	valid_1's auc: 1	valid_1's binary_logloss: 4.06457e-05
# [201]	training's auc: 1	training's binary_logloss: 1.34979e-05	valid_1's auc: 1	valid_1's binary_logloss: 4.04211e-05
# [202]	training's auc: 1	training's binary_logloss: 1.33962e-05	valid_1's auc: 1	valid_1's binary_logloss: 4.01462e-05
# [203]	training's auc: 1	training's binary_logloss: 1.33342e-05	valid_1's auc: 1	valid_1's binary_logloss: 3.99826e-05
# [204]	training's auc: 1	training's binary_logloss: 1.32462e-05	valid_1's auc: 1	valid_1's binary_logloss: 3.97578e-05
# [205]	training's auc: 1	training's binary_logloss: 1.32009e-05	valid_1's auc: 1	valid_1's binary_logloss: 3.96481e-05
# [206]	training's auc: 1	training's binary_logloss: 1.3157e-05	valid_1's auc: 1	valid_1's binary_logloss: 3.95411e-05
# Early stopping, best iteration is:
# [106]	training's auc: 1	training's binary_logloss: 2.7306e-05	valid_1's auc: 1	valid_1's binary_logloss: 6.77386e-05
# [1]	training's auc: 0.798054	training's binary_logloss: 0.638241	valid_1's auc: 0.795941	valid_1's binary_logloss: 0.639075
# Training until validation scores don't improve for 100 rounds
# [2]	training's auc: 0.795983	training's binary_logloss: 0.635461	valid_1's auc: 0.795022	valid_1's binary_logloss: 0.636298
# [3]	training's auc: 0.801064	training's binary_logloss: 0.63202	valid_1's auc: 0.799393	valid_1's binary_logloss: 0.632901
# [4]	training's auc: 0.805128	training's binary_logloss: 0.62876	valid_1's auc: 0.803499	valid_1's binary_logloss: 0.629668
# [5]	training's auc: 0.805357	training's binary_logloss: 0.625791	valid_1's auc: 0.803733	valid_1's binary_logloss: 0.62672
# [6]	training's auc: 0.808672	training's binary_logloss: 0.622254	valid_1's auc: 0.807165	valid_1's binary_logloss: 0.62319
# [7]	training's auc: 0.809176	training's binary_logloss: 0.618955	valid_1's auc: 0.80757	valid_1's binary_logloss: 0.619915
# [8]	training's auc: 0.809488	training's binary_logloss: 0.615693	valid_1's auc: 0.808001	valid_1's binary_logloss: 0.616664
# [9]	training's auc: 0.81077	training's binary_logloss: 0.612516	valid_1's auc: 0.809185	valid_1's binary_logloss: 0.613504
# [10]	training's auc: 0.811523	training's binary_logloss: 0.609562	valid_1's auc: 0.81007	valid_1's binary_logloss: 0.610561
# [11]	training's auc: 0.81097	training's binary_logloss: 0.607163	valid_1's auc: 0.809738	valid_1's binary_logloss: 0.60817
# [12]	training's auc: 0.811233	training's binary_logloss: 0.604407	valid_1's auc: 0.80992	valid_1's binary_logloss: 0.605431
# [13]	training's auc: 0.811711	training's binary_logloss: 0.602493	valid_1's auc: 0.810625	valid_1's binary_logloss: 0.60352
# [14]	training's auc: 0.811496	training's binary_logloss: 0.600353	valid_1's auc: 0.810474	valid_1's binary_logloss: 0.601373
# [15]	training's auc: 0.81132	training's binary_logloss: 0.598084	valid_1's auc: 0.810192	valid_1's binary_logloss: 0.599117
# [16]	training's auc: 0.811627	training's binary_logloss: 0.595407	valid_1's auc: 0.810494	valid_1's binary_logloss: 0.596455
# [17]	training's auc: 0.811912	training's binary_logloss: 0.592853	valid_1's auc: 0.810757	valid_1's binary_logloss: 0.593918
# [18]	training's auc: 0.81202	training's binary_logloss: 0.590298	valid_1's auc: 0.81087	valid_1's binary_logloss: 0.59138
# [19]	training's auc: 0.812119	training's binary_logloss: 0.587962	valid_1's auc: 0.810972	valid_1's binary_logloss: 0.58906
# [20]	training's auc: 0.812277	training's binary_logloss: 0.585649	valid_1's auc: 0.811059	valid_1's binary_logloss: 0.586767
# [21]	training's auc: 0.812571	training's binary_logloss: 0.583321	valid_1's auc: 0.81134	valid_1's binary_logloss: 0.584459
# [22]	training's auc: 0.813133	training's binary_logloss: 0.580937	valid_1's auc: 0.811905	valid_1's binary_logloss: 0.58209
# [23]	training's auc: 0.81313	training's binary_logloss: 0.578774	valid_1's auc: 0.811872	valid_1's binary_logloss: 0.579946
# [24]	training's auc: 0.813071	training's binary_logloss: 0.576825	valid_1's auc: 0.811776	valid_1's binary_logloss: 0.57802
# [25]	training's auc: 0.813525	training's binary_logloss: 0.574782	valid_1's auc: 0.812226	valid_1's binary_logloss: 0.576003
# [26]	training's auc: 0.813377	training's binary_logloss: 0.573077	valid_1's auc: 0.812092	valid_1's binary_logloss: 0.574306
# [27]	training's auc: 0.813583	training's binary_logloss: 0.571042	valid_1's auc: 0.812294	valid_1's binary_logloss: 0.572285
# [28]	training's auc: 0.813706	training's binary_logloss: 0.569124	valid_1's auc: 0.812423	valid_1's binary_logloss: 0.57038
# [29]	training's auc: 0.813757	training's binary_logloss: 0.567249	valid_1's auc: 0.812451	valid_1's binary_logloss: 0.568523
# [30]	training's auc: 0.813811	training's binary_logloss: 0.565512	valid_1's auc: 0.812496	valid_1's binary_logloss: 0.566803
# [31]	training's auc: 0.813757	training's binary_logloss: 0.563986	valid_1's auc: 0.812434	valid_1's binary_logloss: 0.565291
# [32]	training's auc: 0.81399	training's binary_logloss: 0.562181	valid_1's auc: 0.812684	valid_1's binary_logloss: 0.563499
# [33]	training's auc: 0.814154	training's binary_logloss: 0.560661	valid_1's auc: 0.812756	valid_1's binary_logloss: 0.562001
# [34]	training's auc: 0.814299	training's binary_logloss: 0.558929	valid_1's auc: 0.81289	valid_1's binary_logloss: 0.560281
# [35]	training's auc: 0.814343	training's binary_logloss: 0.557432	valid_1's auc: 0.812901	valid_1's binary_logloss: 0.558804
# [36]	training's auc: 0.814646	training's binary_logloss: 0.556203	valid_1's auc: 0.813239	valid_1's binary_logloss: 0.557577
# [37]	training's auc: 0.814721	training's binary_logloss: 0.554848	valid_1's auc: 0.813347	valid_1's binary_logloss: 0.556227
# [38]	training's auc: 0.814791	training's binary_logloss: 0.553278	valid_1's auc: 0.813421	valid_1's binary_logloss: 0.554661
# [39]	training's auc: 0.814784	training's binary_logloss: 0.552086	valid_1's auc: 0.813436	valid_1's binary_logloss: 0.553473
# [40]	training's auc: 0.814917	training's binary_logloss: 0.550543	valid_1's auc: 0.813576	valid_1's binary_logloss: 0.551939
# [41]	training's auc: 0.815135	training's binary_logloss: 0.549085	valid_1's auc: 0.8138	valid_1's binary_logloss: 0.550493
# [42]	training's auc: 0.815464	training's binary_logloss: 0.547573	valid_1's auc: 0.81413	valid_1's binary_logloss: 0.548992
# [43]	training's auc: 0.815738	training's binary_logloss: 0.546112	valid_1's auc: 0.814362	valid_1's binary_logloss: 0.547547
# [44]	training's auc: 0.81574	training's binary_logloss: 0.545022	valid_1's auc: 0.814371	valid_1's binary_logloss: 0.546466
# [45]	training's auc: 0.815886	training's binary_logloss: 0.543664	valid_1's auc: 0.814519	valid_1's binary_logloss: 0.545115
# [46]	training's auc: 0.816011	training's binary_logloss: 0.542319	valid_1's auc: 0.814669	valid_1's binary_logloss: 0.543775
# [47]	training's auc: 0.81612	training's binary_logloss: 0.541165	valid_1's auc: 0.814794	valid_1's binary_logloss: 0.542628
# [48]	training's auc: 0.816151	training's binary_logloss: 0.540078	valid_1's auc: 0.814823	valid_1's binary_logloss: 0.54156
# [49]	training's auc: 0.816247	training's binary_logloss: 0.538902	valid_1's auc: 0.814873	valid_1's binary_logloss: 0.540402
# [50]	training's auc: 0.816242	training's binary_logloss: 0.537942	valid_1's auc: 0.814881	valid_1's binary_logloss: 0.539444
# [51]	training's auc: 0.816238	training's binary_logloss: 0.536905	valid_1's auc: 0.814797	valid_1's binary_logloss: 0.538428
# [52]	training's auc: 0.816255	training's binary_logloss: 0.535837	valid_1's auc: 0.81479	valid_1's binary_logloss: 0.537377
# [53]	training's auc: 0.816553	training's binary_logloss: 0.534594	valid_1's auc: 0.815078	valid_1's binary_logloss: 0.536149
# [54]	training's auc: 0.816642	training's binary_logloss: 0.533462	valid_1's auc: 0.815164	valid_1's binary_logloss: 0.535028
# [55]	training's auc: 0.81687	training's binary_logloss: 0.532487	valid_1's auc: 0.81535	valid_1's binary_logloss: 0.534077
# [56]	training's auc: 0.817074	training's binary_logloss: 0.531533	valid_1's auc: 0.815513	valid_1's binary_logloss: 0.533143
# [57]	training's auc: 0.81722	training's binary_logloss: 0.530424	valid_1's auc: 0.815649	valid_1's binary_logloss: 0.532051
# [58]	training's auc: 0.817269	training's binary_logloss: 0.529491	valid_1's auc: 0.815647	valid_1's binary_logloss: 0.53114
# [59]	training's auc: 0.817459	training's binary_logloss: 0.528432	valid_1's auc: 0.815844	valid_1's binary_logloss: 0.530091
# [60]	training's auc: 0.817629	training's binary_logloss: 0.527396	valid_1's auc: 0.816034	valid_1's binary_logloss: 0.529067
# [61]	training's auc: 0.817701	training's binary_logloss: 0.52652	valid_1's auc: 0.81611	valid_1's binary_logloss: 0.528197
# [62]	training's auc: 0.817826	training's binary_logloss: 0.525658	valid_1's auc: 0.816238	valid_1's binary_logloss: 0.527337
# [63]	training's auc: 0.81797	training's binary_logloss: 0.524668	valid_1's auc: 0.816377	valid_1's binary_logloss: 0.526361
# [64]	training's auc: 0.818148	training's binary_logloss: 0.523751	valid_1's auc: 0.816532	valid_1's binary_logloss: 0.525461
# [65]	training's auc: 0.818249	training's binary_logloss: 0.522888	valid_1's auc: 0.81663	valid_1's binary_logloss: 0.52461
# [66]	training's auc: 0.818373	training's binary_logloss: 0.521964	valid_1's auc: 0.816767	valid_1's binary_logloss: 0.523695
# ...
# [875]	training's auc: 0.950774	training's binary_logloss: 0.196407	valid_1's auc: 0.945303	valid_1's binary_logloss: 0.202386
# [876]	training's auc: 0.950802	training's binary_logloss: 0.196378	valid_1's auc: 0.945329	valid_1's binary_logloss: 0.202361
# [877]	training's auc: 0.95083	training's binary_logloss: 0.196344	valid_1's auc: 0.945356	valid_1's binary_logloss: 0.20233
# [878]	training's auc: 0.950849	training's binary_logloss: 0.19632	valid_1's auc: 0.945374	valid_1's binary_logloss: 0.202306
# [879]	training's auc: 0.950892	training's binary_logloss: 0.196277	valid_1's auc: 0.945414	valid_1's binary_logloss: 0.202266
# [880]	training's auc: 0.950936	training's binary_logloss: 0.196235	valid_1's auc: 0.945452	valid_1's binary_logloss: 0.202228
# [881]	training's auc: 0.950942	training's binary_logloss: 0.196222	valid_1's auc: 0.945459	valid_1's binary_logloss: 0.202215
# [882]	training's auc: 0.950978	training's binary_logloss: 0.196179	valid_1's auc: 0.945491	valid_1's binary_logloss: 0.202179
# [883]	training's auc: 0.951002	training's binary_logloss: 0.196151	valid_1's auc: 0.945512	valid_1's binary_logloss: 0.202154
# [884]	training's auc: 0.951029	training's binary_logloss: 0.196118	valid_1's auc: 0.945538	valid_1's binary_logloss: 0.202124
# [885]	training's auc: 0.951077	training's binary_logloss: 0.196073	valid_1's auc: 0.945583	valid_1's binary_logloss: 0.202083
# [886]	training's auc: 0.951107	training's binary_logloss: 0.196038	valid_1's auc: 0.945609	valid_1's binary_logloss: 0.202053
# [887]	training's auc: 0.951131	training's binary_logloss: 0.196002	valid_1's auc: 0.945631	valid_1's binary_logloss: 0.202022
# [888]	training's auc: 0.951176	training's binary_logloss: 0.195956	valid_1's auc: 0.945671	valid_1's binary_logloss: 0.201982
# [889]	training's auc: 0.951217	training's binary_logloss: 0.195918	valid_1's auc: 0.945714	valid_1's binary_logloss: 0.201943
# [890]	training's auc: 0.951242	training's binary_logloss: 0.195889	valid_1's auc: 0.945738	valid_1's binary_logloss: 0.201917
# [891]	training's auc: 0.9513	training's binary_logloss: 0.195837	valid_1's auc: 0.945795	valid_1's binary_logloss: 0.201867
# [892]	training's auc: 0.951354	training's binary_logloss: 0.195785	valid_1's auc: 0.945847	valid_1's binary_logloss: 0.201819
# [893]	training's auc: 0.95137	training's binary_logloss: 0.195764	valid_1's auc: 0.945865	valid_1's binary_logloss: 0.201798
# [894]	training's auc: 0.951407	training's binary_logloss: 0.195727	valid_1's auc: 0.945896	valid_1's binary_logloss: 0.201767
# [895]	training's auc: 0.951463	training's binary_logloss: 0.195673	valid_1's auc: 0.945953	valid_1's binary_logloss: 0.201715
# [896]	training's auc: 0.951511	training's binary_logloss: 0.195622	valid_1's auc: 0.945998	valid_1's binary_logloss: 0.201667
# [897]	training's auc: 0.951537	training's binary_logloss: 0.19559	valid_1's auc: 0.946021	valid_1's binary_logloss: 0.201641
# [898]	training's auc: 0.951561	training's binary_logloss: 0.195563	valid_1's auc: 0.946039	valid_1's binary_logloss: 0.201621
# [899]	training's auc: 0.9516	training's binary_logloss: 0.195523	valid_1's auc: 0.946079	valid_1's binary_logloss: 0.201582
# [900]	training's auc: 0.951632	training's binary_logloss: 0.195486	valid_1's auc: 0.946107	valid_1's binary_logloss: 0.201552
# [901]	training's auc: 0.95167	training's binary_logloss: 0.195446	valid_1's auc: 0.946141	valid_1's binary_logloss: 0.201517
# [902]	training's auc: 0.951712	training's binary_logloss: 0.195402	valid_1's auc: 0.946184	valid_1's binary_logloss: 0.201473
# [903]	training's auc: 0.951747	training's binary_logloss: 0.195364	valid_1's auc: 0.946218	valid_1's binary_logloss: 0.201441
# [904]	training's auc: 0.95178	training's binary_logloss: 0.195324	valid_1's auc: 0.94625	valid_1's binary_logloss: 0.201404
# [905]	training's auc: 0.951825	training's binary_logloss: 0.19528	valid_1's auc: 0.946288	valid_1's binary_logloss: 0.201367
# [906]	training's auc: 0.951848	training's binary_logloss: 0.195253	valid_1's auc: 0.946308	valid_1's binary_logloss: 0.201344
# [907]	training's auc: 0.951896	training's binary_logloss: 0.195204	valid_1's auc: 0.946356	valid_1's binary_logloss: 0.201299
# [908]	training's auc: 0.951949	training's binary_logloss: 0.195151	valid_1's auc: 0.946406	valid_1's binary_logloss: 0.201249
# [909]	training's auc: 0.951983	training's binary_logloss: 0.195106	valid_1's auc: 0.946439	valid_1's binary_logloss: 0.201207
# [910]	training's auc: 0.952021	training's binary_logloss: 0.195061	valid_1's auc: 0.946478	valid_1's binary_logloss: 0.201164
# [911]	training's auc: 0.952036	training's binary_logloss: 0.195039	valid_1's auc: 0.946487	valid_1's binary_logloss: 0.201151
# [912]	training's auc: 0.952058	training's binary_logloss: 0.19501	valid_1's auc: 0.946503	valid_1's binary_logloss: 0.201128
# [913]	training's auc: 0.952078	training's binary_logloss: 0.19498	valid_1's auc: 0.946522	valid_1's binary_logloss: 0.201099
# [914]	training's auc: 0.952101	training's binary_logloss: 0.194954	valid_1's auc: 0.946543	valid_1's binary_logloss: 0.201077
# [915]	training's auc: 0.952167	training's binary_logloss: 0.194894	valid_1's auc: 0.946608	valid_1's binary_logloss: 0.201022
# [916]	training's auc: 0.952213	training's binary_logloss: 0.194846	valid_1's auc: 0.946656	valid_1's binary_logloss: 0.200974
# [917]	training's auc: 0.952249	training's binary_logloss: 0.194806	valid_1's auc: 0.94669	valid_1's binary_logloss: 0.200938
# [918]	training's auc: 0.952293	training's binary_logloss: 0.194758	valid_1's auc: 0.946729	valid_1's binary_logloss: 0.200896
# [919]	training's auc: 0.952351	training's binary_logloss: 0.194702	valid_1's auc: 0.946784	valid_1's binary_logloss: 0.200845
# [920]	training's auc: 0.952417	training's binary_logloss: 0.194642	valid_1's auc: 0.94684	valid_1's binary_logloss: 0.200793
# [921]	training's auc: 0.95247	training's binary_logloss: 0.194593	valid_1's auc: 0.946889	valid_1's binary_logloss: 0.20075
# [922]	training's auc: 0.952505	training's binary_logloss: 0.194558	valid_1's auc: 0.946922	valid_1's binary_logloss: 0.200718
# [923]	training's auc: 0.952549	training's binary_logloss: 0.194511	valid_1's auc: 0.946964	valid_1's binary_logloss: 0.200676
# [924]	training's auc: 0.952584	training's binary_logloss: 0.194471	valid_1's auc: 0.946995	valid_1's binary_logloss: 0.200642
# [925]	training's auc: 0.952627	training's binary_logloss: 0.194424	valid_1's auc: 0.947036	valid_1's binary_logloss: 0.200599
# [926]	training's auc: 0.952667	training's binary_logloss: 0.194382	valid_1's auc: 0.947071	valid_1's binary_logloss: 0.200563
# [927]	training's auc: 0.952693	training's binary_logloss: 0.194346	valid_1's auc: 0.947096	valid_1's binary_logloss: 0.20053
# [928]	training's auc: 0.95275	training's binary_logloss: 0.19429	valid_1's auc: 0.947153	valid_1's binary_logloss: 0.200476
# [929]	training's auc: 0.952811	training's binary_logloss: 0.194238	valid_1's auc: 0.947205	valid_1's binary_logloss: 0.200431
# [930]	training's auc: 0.952839	training's binary_logloss: 0.194203	valid_1's auc: 0.947228	valid_1's binary_logloss: 0.200403
# [931]	training's auc: 0.95286	training's binary_logloss: 0.194171	valid_1's auc: 0.947248	valid_1's binary_logloss: 0.200374
# [932]	training's auc: 0.952883	training's binary_logloss: 0.194138	valid_1's auc: 0.947268	valid_1's binary_logloss: 0.200346
# [933]	training's auc: 0.952916	training's binary_logloss: 0.194099	valid_1's auc: 0.947299	valid_1's binary_logloss: 0.200312
# [934]	training's auc: 0.952946	training's binary_logloss: 0.194065	valid_1's auc: 0.947328	valid_1's binary_logloss: 0.200281
# [935]	training's auc: 0.953001	training's binary_logloss: 0.194006	valid_1's auc: 0.947385	valid_1's binary_logloss: 0.200225
# [936]	training's auc: 0.95304	training's binary_logloss: 0.193963	valid_1's auc: 0.947427	valid_1's binary_logloss: 0.200184
# [937]	training's auc: 0.953062	training's binary_logloss: 0.193934	valid_1's auc: 0.947448	valid_1's binary_logloss: 0.200158
# [938]	training's auc: 0.953095	training's binary_logloss: 0.193894	valid_1's auc: 0.947482	valid_1's binary_logloss: 0.200118
# [939]	training's auc: 0.953139	training's binary_logloss: 0.193852	valid_1's auc: 0.947522	valid_1's binary_logloss: 0.200081
# [940]	training's auc: 0.953181	training's binary_logloss: 0.193811	valid_1's auc: 0.947566	valid_1's binary_logloss: 0.200044
# [941]	training's auc: 0.953223	training's binary_logloss: 0.193762	valid_1's auc: 0.947602	valid_1's binary_logloss: 0.200001
# [942]	training's auc: 0.953268	training's binary_logloss: 0.193716	valid_1's auc: 0.947647	valid_1's binary_logloss: 0.199957
# [943]	training's auc: 0.953308	training's binary_logloss: 0.193677	valid_1's auc: 0.947686	valid_1's binary_logloss: 0.199921
# [944]	training's auc: 0.953361	training's binary_logloss: 0.193621	valid_1's auc: 0.947737	valid_1's binary_logloss: 0.19987
# [945]	training's auc: 0.953391	training's binary_logloss: 0.193589	valid_1's auc: 0.947764	valid_1's binary_logloss: 0.199843
# [946]	training's auc: 0.953425	training's binary_logloss: 0.19355	valid_1's auc: 0.947804	valid_1's binary_logloss: 0.199803
# [947]	training's auc: 0.953445	training's binary_logloss: 0.193519	valid_1's auc: 0.947823	valid_1's binary_logloss: 0.199776
# [948]	training's auc: 0.953465	training's binary_logloss: 0.193488	valid_1's auc: 0.947841	valid_1's binary_logloss: 0.199751
# [949]	training's auc: 0.953501	training's binary_logloss: 0.193448	valid_1's auc: 0.947873	valid_1's binary_logloss: 0.199716
# [950]	training's auc: 0.953537	training's binary_logloss: 0.19341	valid_1's auc: 0.947904	valid_1's binary_logloss: 0.199683
# [951]	training's auc: 0.953577	training's binary_logloss: 0.193365	valid_1's auc: 0.947948	valid_1's binary_logloss: 0.199637
# [952]	training's auc: 0.953617	training's binary_logloss: 0.19332	valid_1's auc: 0.947985	valid_1's binary_logloss: 0.199596
# [953]	training's auc: 0.953665	training's binary_logloss: 0.19327	valid_1's auc: 0.948031	valid_1's binary_logloss: 0.19955
# [954]	training's auc: 0.953699	training's binary_logloss: 0.193232	valid_1's auc: 0.948063	valid_1's binary_logloss: 0.199517
# [955]	training's auc: 0.953712	training's binary_logloss: 0.193217	valid_1's auc: 0.94807	valid_1's binary_logloss: 0.19951
# [956]	training's auc: 0.953726	training's binary_logloss: 0.193201	valid_1's auc: 0.948076	valid_1's binary_logloss: 0.199505
# [957]	training's auc: 0.953758	training's binary_logloss: 0.193161	valid_1's auc: 0.948108	valid_1's binary_logloss: 0.199467
# [958]	training's auc: 0.953798	training's binary_logloss: 0.193118	valid_1's auc: 0.948148	valid_1's binary_logloss: 0.199427
# [959]	training's auc: 0.953837	training's binary_logloss: 0.193074	valid_1's auc: 0.948187	valid_1's binary_logloss: 0.199386
# [960]	training's auc: 0.953879	training's binary_logloss: 0.193027	valid_1's auc: 0.948227	valid_1's binary_logloss: 0.199345
# [961]	training's auc: 0.953915	training's binary_logloss: 0.192986	valid_1's auc: 0.948264	valid_1's binary_logloss: 0.199306
# [962]	training's auc: 0.953949	training's binary_logloss: 0.192946	valid_1's auc: 0.948293	valid_1's binary_logloss: 0.199272
# [963]	training's auc: 0.95398	training's binary_logloss: 0.19291	valid_1's auc: 0.94832	valid_1's binary_logloss: 0.199244
# [964]	training's auc: 0.954014	training's binary_logloss: 0.192869	valid_1's auc: 0.948349	valid_1's binary_logloss: 0.199209
# [965]	training's auc: 0.954044	training's binary_logloss: 0.19284	valid_1's auc: 0.948374	valid_1's binary_logloss: 0.199186
# [966]	training's auc: 0.954069	training's binary_logloss: 0.192814	valid_1's auc: 0.948398	valid_1's binary_logloss: 0.199161
# [967]	training's auc: 0.9541	training's binary_logloss: 0.192778	valid_1's auc: 0.948432	valid_1's binary_logloss: 0.199124
# [968]	training's auc: 0.954128	training's binary_logloss: 0.192746	valid_1's auc: 0.948457	valid_1's binary_logloss: 0.199095
# [969]	training's auc: 0.954154	training's binary_logloss: 0.192711	valid_1's auc: 0.94848	valid_1's binary_logloss: 0.199065
# [970]	training's auc: 0.954205	training's binary_logloss: 0.192658	valid_1's auc: 0.948524	valid_1's binary_logloss: 0.199021
# [971]	training's auc: 0.954213	training's binary_logloss: 0.192648	valid_1's auc: 0.948524	valid_1's binary_logloss: 0.199019
# [972]	training's auc: 0.954222	training's binary_logloss: 0.192638	valid_1's auc: 0.948525	valid_1's binary_logloss: 0.199017
# [973]	training's auc: 0.954248	training's binary_logloss: 0.192612	valid_1's auc: 0.948551	valid_1's binary_logloss: 0.198991
# [974]	training's auc: 0.954266	training's binary_logloss: 0.192588	valid_1's auc: 0.948569	valid_1's binary_logloss: 0.19897
# [975]	training's auc: 0.95428	training's binary_logloss: 0.192573	valid_1's auc: 0.948576	valid_1's binary_logloss: 0.198961
# [976]	training's auc: 0.954297	training's binary_logloss: 0.192549	valid_1's auc: 0.948594	valid_1's binary_logloss: 0.198939
# [977]	training's auc: 0.954321	training's binary_logloss: 0.19252	valid_1's auc: 0.94862	valid_1's binary_logloss: 0.198911
# [978]	training's auc: 0.954349	training's binary_logloss: 0.192489	valid_1's auc: 0.948649	valid_1's binary_logloss: 0.198879
# [979]	training's auc: 0.954379	training's binary_logloss: 0.192454	valid_1's auc: 0.948678	valid_1's binary_logloss: 0.198846
# [980]	training's auc: 0.954415	training's binary_logloss: 0.192416	valid_1's auc: 0.948715	valid_1's binary_logloss: 0.198808
# [981]	training's auc: 0.954463	training's binary_logloss: 0.192367	valid_1's auc: 0.948766	valid_1's binary_logloss: 0.19876
# [982]	training's auc: 0.954497	training's binary_logloss: 0.192326	valid_1's auc: 0.948798	valid_1's binary_logloss: 0.198722
# [983]	training's auc: 0.954538	training's binary_logloss: 0.192281	valid_1's auc: 0.948834	valid_1's binary_logloss: 0.198682
# [984]	training's auc: 0.954562	training's binary_logloss: 0.192247	valid_1's auc: 0.948855	valid_1's binary_logloss: 0.198653
# [985]	training's auc: 0.9546	training's binary_logloss: 0.192202	valid_1's auc: 0.948896	valid_1's binary_logloss: 0.19861
# [986]	training's auc: 0.95464	training's binary_logloss: 0.192158	valid_1's auc: 0.948933	valid_1's binary_logloss: 0.198571
# [987]	training's auc: 0.954682	training's binary_logloss: 0.192111	valid_1's auc: 0.948977	valid_1's binary_logloss: 0.198527
# [988]	training's auc: 0.954722	training's binary_logloss: 0.192066	valid_1's auc: 0.94902	valid_1's binary_logloss: 0.198484
# [989]	training's auc: 0.954741	training's binary_logloss: 0.192039	valid_1's auc: 0.949037	valid_1's binary_logloss: 0.19846
# [990]	training's auc: 0.954752	training's binary_logloss: 0.192022	valid_1's auc: 0.949041	valid_1's binary_logloss: 0.198448
# [991]	training's auc: 0.954764	training's binary_logloss: 0.192006	valid_1's auc: 0.94905	valid_1's binary_logloss: 0.198437
# [992]	training's auc: 0.954772	training's binary_logloss: 0.191995	valid_1's auc: 0.949051	valid_1's binary_logloss: 0.198434
# [993]	training's auc: 0.954799	training's binary_logloss: 0.191964	valid_1's auc: 0.949077	valid_1's binary_logloss: 0.198406
# [994]	training's auc: 0.954823	training's binary_logloss: 0.191934	valid_1's auc: 0.949102	valid_1's binary_logloss: 0.198375
# [995]	training's auc: 0.954843	training's binary_logloss: 0.191911	valid_1's auc: 0.949127	valid_1's binary_logloss: 0.198346
# [996]	training's auc: 0.954872	training's binary_logloss: 0.191883	valid_1's auc: 0.949158	valid_1's binary_logloss: 0.19832
# [997]	training's auc: 0.954909	training's binary_logloss: 0.191842	valid_1's auc: 0.94919	valid_1's binary_logloss: 0.198284
# [998]	training's auc: 0.954953	training's binary_logloss: 0.191798	valid_1's auc: 0.949235	valid_1's binary_logloss: 0.198243
# [999]	training's auc: 0.954977	training's binary_logloss: 0.191762	valid_1's auc: 0.94926	valid_1's binary_logloss: 0.198208
# [1000]	training's auc: 0.955018	training's binary_logloss: 0.191716	valid_1's auc: 0.949302	valid_1's binary_logloss: 0.198165
# Did not meet early stopping. Best iteration is:
# [1000]	training's auc: 0.955018	training's binary_logloss: 0.191716	valid_1's auc: 0.949302	valid_1's binary_logloss: 0.198165

# %%
#提取预测的概率值
templabel = test_label[targets]

#使用index存放候选集
index = pd.DataFrame()
index['ncodpers'] = test_label['ncodpers']

# %%
#概率第一名
temp =  templabel.idxmax(axis=1)
index ['one'] = temp

count = 0
for i in temp:
    templabel[i][count] = 0
    count+=1

#概率第二名
temp =  templabel.idxmax(axis=1)
index['two'] = temp

count = 0
for i in temp:
    templabel[i][count] = 0
    count+=1

#概率第3名
temp =  templabel.idxmax(axis=1)
index['three'] = temp

count = 0
for i in temp:
    templabel[i][count] = 0
    count+=1

#概率第4名
temp =  templabel.idxmax(axis=1)
index['fourth'] = temp

count = 0
for i in temp:
    templabel[i][count] = 0
    count+=1
    
#概率第5名
temp =  templabel.idxmax(axis=1)
index['five'] = temp

count = 0
for i in temp:
    templabel[i][count] = 0
    count+=1

#概率第6名
temp =  templabel.idxmax(axis=1)
index['six'] = temp

count = 0
for i in temp:
    templabel[i][count] = 0
    count+=1
    
#概率第7名
temp =  templabel.idxmax(axis=1)
index['seven'] = temp

count = 0
for i in temp:
    templabel[i][count] = 0
    count+=1
# Out:
# C:\Users\xueliang.chen\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3326: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
index
# Out:
#        ncodpers                one                two              three  \
# 0        657788   ind_cco_fin_ult1    ind_recibo_ult1   ind_cno_fin_ult1
# 1        657794  ind_dela_fin_ult1   ind_cco_fin_ult1  ind_ecue_fin_ult1
# 2        657770   ind_cco_fin_ult1    ind_recibo_ult1   ind_cno_fin_ult1
# 3        658056   ind_cco_fin_ult1   ind_cno_fin_ult1  ind_reca_fin_ult1
# 4        657869   ind_cco_fin_ult1  ind_ctop_fin_ult1    ind_recibo_ult1
# ...         ...                ...                ...                ...
# 29157   1166847   ind_cco_fin_ult1    ind_recibo_ult1   ind_cno_fin_ult1
# 29158   1166605   ind_cco_fin_ult1  ind_reca_fin_ult1    ind_recibo_ult1
# 29159   1166829   ind_cco_fin_ult1    ind_recibo_ult1   ind_cno_fin_ult1
# 29160   1166827   ind_cco_fin_ult1    ind_recibo_ult1   ind_cno_fin_ult1
# 29161   1166781   ind_cco_fin_ult1    ind_recibo_ult1   ind_cno_fin_ult1
#
#                   fourth               five                six  \
# 0      ind_ctop_fin_ult1    ind_nomina_ult1  ind_nom_pens_ult1
# 1        ind_recibo_ult1   ind_cno_fin_ult1  ind_nom_pens_ult1
# 2      ind_ctop_fin_ult1  ind_valo_fin_ult1  ind_tjcr_fin_ult1
# 3        ind_recibo_ult1    ind_nomina_ult1  ind_nom_pens_ult1
# 4       ind_cno_fin_ult1  ind_nom_pens_ult1    ind_nomina_ult1
# ...                  ...                ...                ...
# 29157  ind_nom_pens_ult1    ind_nomina_ult1  ind_ecue_fin_ult1
# 29158   ind_cno_fin_ult1  ind_ecue_fin_ult1  ind_nom_pens_ult1
# 29159  ind_nom_pens_ult1    ind_nomina_ult1  ind_reca_fin_ult1
# 29160  ind_ecue_fin_ult1  ind_reca_fin_ult1  ind_nom_pens_ult1
# 29161  ind_ecue_fin_ult1  ind_reca_fin_ult1    ind_nomina_ult1
#
#                    seven
# 0      ind_reca_fin_ult1
# 1        ind_nomina_ult1
# 2      ind_ecue_fin_ult1
# 3      ind_ecue_fin_ult1
# 4      ind_ecue_fin_ult1
# ...                  ...
# 29157  ind_reca_fin_ult1
# 29158    ind_nomina_ult1
# 29159  ind_ecue_fin_ult1
# 29160  ind_ahor_fin_ult1
# 29161  ind_nom_pens_ult1
#
# [29162 rows x 8 columns]

# %%
index['added_products'] = index['one']+' '+index['two']+" "+index['three']+" "+index['fourth']+' '+index['five']+" "+index['six']+" "+index['seven']

#删除多余列
temp = index.columns.drop(['ncodpers','added_products'])

for i in temp:
    del index[i]
    
submission = pd.read_csv('sub.csv')

submission['added_products'] = pd.Series(index['added_products'])

submission.to_csv('sub.csv', index=False)

# %%
submission
# Out:
#        ncodpers                                     added_products
# 0        657788  ind_cco_fin_ult1 ind_recibo_ult1 ind_cno_fin_u...
# 1        657794  ind_dela_fin_ult1 ind_cco_fin_ult1 ind_ecue_fi...
# 2        657770  ind_cco_fin_ult1 ind_recibo_ult1 ind_cno_fin_u...
# 3        658056  ind_cco_fin_ult1 ind_cno_fin_ult1 ind_reca_fin...
# 4        657869  ind_cco_fin_ult1 ind_ctop_fin_ult1 ind_recibo_...
# ...         ...                                                ...
# 29157   1166847  ind_cco_fin_ult1 ind_recibo_ult1 ind_cno_fin_u...
# 29158   1166605  ind_cco_fin_ult1 ind_reca_fin_ult1 ind_recibo_...
# 29159   1166829  ind_cco_fin_ult1 ind_recibo_ult1 ind_cno_fin_u...
# 29160   1166827  ind_cco_fin_ult1 ind_recibo_ult1 ind_cno_fin_u...
# 29161   1166781  ind_cco_fin_ult1 ind_recibo_ult1 ind_cno_fin_u...
#
# [29162 rows x 2 columns]

# %%
submission['added_products'][0]
# Out:
# 'ind_cco_fin_ult1 ind_recibo_ult1 ind_cno_fin_ult1 ind_ctop_fin_ult1 ind_nomina_ult1 ind_nom_pens_ult1 ind_reca_fin_ult1'
